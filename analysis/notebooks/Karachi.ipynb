# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('KarachiBuildings.csv')

# %%
df['building'].value_counts()
# Out:
# yes               43507
# house             33448
# apartments         5252
# bunglows            880
# industrial          620
# commercial          324
# residential         322
# university          193
# construction        162
# school              130
# mosque              117
# warehouse           103
# hospital            101
# no                   94
# college              48
# roof                 29
# detached             23
# ruins                22
# hangar               19
# hotel                13
# stadium              13
# farm_auxiliary        9
# terrace               9
# office                9
# public                8
# garage                7
# bungalow              5
# retail                5
# greenhouse            4
# bunker                4
# service               3
# dormitory             3
# transportation        2
# grandstand            2
# mall                  2
# sports_centre         2
# civic                 2
# shed                  2
# church                2
# parking               2
# carport               1
# tower No-1            1
# government            1
# yrs                   1
# ballroom              1
# Name: building, dtype: int64

# %%
df
# Out:
#                                         name name_en building  building_l  \
# 0                                 Allah Wali     NaN      yes         NaN
# 1                                   Baghdadi     NaN      yes         NaN
# 2                                    Qayyumi     NaN      yes         NaN
# 3                                        NaN     NaN      yes         NaN
# 4                                        NaN     NaN      yes         NaN
# ...                                      ...     ...      ...         ...
# 85502                                    NaN     NaN      yes         3.0
# 85503                                    NaN     NaN      yes         3.0
# 85504                                    NaN     NaN      yes         NaN
# 85505  Karachi Public School (Korangi Creek)     NaN      yes         6.0
# 85506              People's Football Stadium     NaN      yes         NaN
#
#        building_m addr_full addr_house  \
# 0             NaN       NaN        NaN
# 1             NaN       NaN        NaN
# 2             NaN       NaN        NaN
# 3             NaN       NaN        NaN
# 4             NaN       NaN        NaN
# ...           ...       ...        ...
# 85502         NaN       NaN        NaN
# 85503         NaN       NaN        NaN
# 85504         NaN       NaN        NaN
# 85505         NaN       NaN        NaN
# 85506         NaN       NaN        NaN
#
#                                               addr_stree addr_city office  \
# 0                                                    NaN       NaN    NaN
# 1                                                    NaN       NaN    NaN
# 2                                                    NaN       NaN    NaN
# 3                                                    NaN       NaN    NaN
# 4                                                    NaN       NaN    NaN
# ...                                                  ...       ...    ...
# 85502                                      PECHS Block 2   Karachi    NaN
# 85503                                      PECHS Block 2   Karachi    NaN
# 85504                                                NaN       NaN    NaN
# 85505                                                NaN       NaN    NaN
# 85506  Mauripur Rd, Nayabad Liaquat Colony, Karachi, ...   Karachi    NaN
#
#        ... ADM2ALT2EN ADM1_EN  ADM1_PCODE   ADM0_EN  ADM0_PCODE        date  \
# 0      ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 1      ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 2      ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 3      ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 4      ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# ...    ...        ...     ...         ...       ...         ...         ...
# 85502  ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 85503  ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 85504  ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 85505  ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
# 85506  ...        NaN   Sindh         PK7  Pakistan          PK  2022/09/02
#
#           validOn validTo        lon        lat
# 0      2022/09/09     NaN  66.976520  24.870707
# 1      2022/09/09     NaN  66.994912  24.860076
# 2      2022/09/09     NaN  66.992142  24.865603
# 3      2022/09/09     NaN  66.998488  24.869432
# 4      2022/09/09     NaN  66.998157  24.869155
# ...           ...     ...        ...        ...
# 85502  2022/09/09     NaN  67.058398  24.870653
# 85503  2022/09/09     NaN  67.058432  24.870773
# 85504  2022/09/09     NaN  66.971928  24.834162
# 85505  2022/09/09     NaN  67.103170  24.817748
# 85506  2022/09/09     NaN  66.988293  24.858577
#
# [85507 rows x 30 columns]

# %%
df['name'] = df.index.map(lambda i: f'KarachiBuilding{i}')

# %%
df
# Out:
#                        name name_en building  building_l  building_m  \
# 0          KarachiBuilding0     NaN      yes         NaN         NaN
# 1          KarachiBuilding1     NaN      yes         NaN         NaN
# 2          KarachiBuilding2     NaN      yes         NaN         NaN
# 3          KarachiBuilding3     NaN      yes         NaN         NaN
# 4          KarachiBuilding4     NaN      yes         NaN         NaN
# ...                     ...     ...      ...         ...         ...
# 85502  KarachiBuilding85502     NaN      yes         3.0         NaN
# 85503  KarachiBuilding85503     NaN      yes         3.0         NaN
# 85504  KarachiBuilding85504     NaN      yes         NaN         NaN
# 85505  KarachiBuilding85505     NaN      yes         6.0         NaN
# 85506  KarachiBuilding85506     NaN      yes         NaN         NaN
#
#       addr_full addr_house                                         addr_stree  \
# 0           NaN        NaN                                                NaN
# 1           NaN        NaN                                                NaN
# 2           NaN        NaN                                                NaN
# 3           NaN        NaN                                                NaN
# 4           NaN        NaN                                                NaN
# ...         ...        ...                                                ...
# 85502       NaN        NaN                                      PECHS Block 2
# 85503       NaN        NaN                                      PECHS Block 2
# 85504       NaN        NaN                                                NaN
# 85505       NaN        NaN                                                NaN
# 85506       NaN        NaN  Mauripur Rd, Nayabad Liaquat Colony, Karachi, ...
#
#       addr_city office  ... ADM2ALT2EN ADM1_EN  ADM1_PCODE   ADM0_EN  \
# 0           NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# 1           NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# 2           NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# 3           NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# 4           NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# ...         ...    ...  ...        ...     ...         ...       ...
# 85502   Karachi    NaN  ...        NaN   Sindh         PK7  Pakistan
# 85503   Karachi    NaN  ...        NaN   Sindh         PK7  Pakistan
# 85504       NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# 85505       NaN    NaN  ...        NaN   Sindh         PK7  Pakistan
# 85506   Karachi    NaN  ...        NaN   Sindh         PK7  Pakistan
#
#        ADM0_PCODE        date     validOn validTo        lon        lat
# 0              PK  2022/09/02  2022/09/09     NaN  66.976520  24.870707
# 1              PK  2022/09/02  2022/09/09     NaN  66.994912  24.860076
# 2              PK  2022/09/02  2022/09/09     NaN  66.992142  24.865603
# 3              PK  2022/09/02  2022/09/09     NaN  66.998488  24.869432
# 4              PK  2022/09/02  2022/09/09     NaN  66.998157  24.869155
# ...           ...         ...         ...     ...        ...        ...
# 85502          PK  2022/09/02  2022/09/09     NaN  67.058398  24.870653
# 85503          PK  2022/09/02  2022/09/09     NaN  67.058432  24.870773
# 85504          PK  2022/09/02  2022/09/09     NaN  66.971928  24.834162
# 85505          PK  2022/09/02  2022/09/09     NaN  67.103170  24.817748
# 85506          PK  2022/09/02  2022/09/09     NaN  66.988293  24.858577
#
# [85507 rows x 30 columns]

# %%
house = ['yes', 'apartments', 'residential', 'house', 'dormitory', 'bungalow', 'semidetached_house']
school = ['school', 'university', 'kindergarten', 'college']
public_transport = ['train_station', 'transportation']
hospital = ['hospital']

# %%
toilet = ['toilets']
civic = ['civic']
public = ['public']
fire = ['fire_station']
sports = ['grandstand', 'pavilion', 'riding_hall', 'sports_hall', 'sports_centre', 'stadium']
govt = ['government']
supermarket = ['supermarket']

df_toilet = df[df['building'].isin(toilet)]
df_civic = df[df['building'].isin(civic)]
df_public = df[df['building'].isin(public)]
df_fire = df[df['building'].isin(fire)]
df_sports = df[df['building'].isin(sports)]
df_govt = df[df['building'].isin(govt)]
df_supermarket = df[df['building'].isin(supermarket)]

df_toilet.to_csv('Toilet.csv', index = False)
df_civic.to_csv('Civic.csv', index = False)
df_public.to_csv('Public.csv', index = False)
df_fire.to_csv('Fire.csv', index = False)
df_sports.to_csv('Sports.csv', index = False)
df_govt.to_csv('Government.csv', index = False)
df_supermarket.to_csv('Supermarket.csv', index = False)

# %%
df_building = df[df['building'].isin(house)]
df_school = df[df['building'].isin(school)]
df_pt = df[df['building'].isin(public_transport)]
df_hospital = df[df['building'].isin(hospital)]

# %%
df_building.to_csv('KarachiBuildingsFinal.csv', index = False)
df_school.to_csv('School.csv', index = False)
df_pt.to_csv('Transport.csv', index = False)
df_hospital.to_csv('Hospital.csv', index = False)

# %%
df_sports
# Out:
#                        name name_en       building  building_l  building_m  \
# 539      KarachiBuilding539     NaN     grandstand         NaN         NaN
# 4624    KarachiBuilding4624     NaN  sports_centre         3.0         NaN
# 5033    KarachiBuilding5033     NaN        stadium         1.0         NaN
# 5034    KarachiBuilding5034     NaN        stadium         1.0         NaN
# 41873  KarachiBuilding41873     NaN        stadium         NaN         NaN
# 57772  KarachiBuilding57772     NaN  sports_centre         NaN         NaN
# 57783  KarachiBuilding57783     NaN        stadium         1.0         NaN
# 63411  KarachiBuilding63411     NaN        stadium         1.0         NaN
# 80613  KarachiBuilding80613     NaN        stadium         NaN         NaN
# 80976  KarachiBuilding80976     NaN     grandstand         NaN         NaN
# 83397  KarachiBuilding83397     NaN        stadium         NaN         NaN
# 83398  KarachiBuilding83398     NaN        stadium         NaN         NaN
# 83399  KarachiBuilding83399     NaN        stadium         NaN         NaN
# 84556  KarachiBuilding84556     NaN        stadium         NaN         NaN
# 84557  KarachiBuilding84557     NaN        stadium         NaN         NaN
# 84565  KarachiBuilding84565     NaN        stadium         4.0         NaN
# 84566  KarachiBuilding84566     NaN        stadium         4.0         NaN
#
#       addr_full addr_house    addr_stree addr_city office  ... ADM2ALT2EN  \
# 539         NaN        NaN           NaN       NaN    NaN  ...        NaN
# 4624        NaN        NaN           NaN       NaN    NaN  ...        NaN
# 5033        NaN        NaN           NaN       NaN    NaN  ...        NaN
# 5034        NaN        NaN           NaN       NaN    NaN  ...        NaN
# 41873       NaN        NaN  Stadium Road   Karachi    NaN  ...        NaN
# 57772       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 57783       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 63411       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 80613       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 80976       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 83397       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 83398       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 83399       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 84556       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 84557       NaN        NaN           NaN       NaN    NaN  ...        NaN
# 84565       NaN        NaN  Stadium Road   Karachi    NaN  ...        NaN
# 84566       NaN        NaN  Stadium Road   Karachi    NaN  ...        NaN
#
#       ADM1_EN  ADM1_PCODE   ADM0_EN  ADM0_PCODE        date     validOn  \
# 539     Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 4624    Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 5033    Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 5034    Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 41873   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 57772   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 57783   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 63411   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 80613   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 80976   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 83397   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 83398   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 83399   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 84556   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 84557   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 84565   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
# 84566   Sindh         PK7  Pakistan          PK  2022/09/02  2022/09/09
#
#       validTo        lon        lat
# 539       NaN  67.247559  24.923412
# 4624      NaN  67.054067  24.881922
# 5033      NaN  67.053468  24.881526
# 5034      NaN  67.053758  24.881351
# 41873     NaN  67.081908  24.894989
# 57772     NaN  67.115530  24.933101
# 57783     NaN  67.053654  24.881054
# 63411     NaN  67.053357  24.881221
# 80613     NaN  67.008553  24.861312
# 80976     NaN  67.148131  24.793432
# 83397     NaN  67.008521  24.861966
# 83398     NaN  67.009165  24.862003
# 83399     NaN  67.009496  24.861622
# 84556     NaN  66.991002  24.851065
# 84557     NaN  66.991869  24.850680
# 84565     NaN  67.081215  24.896117
# 84566     NaN  67.082338  24.895547
#
# [17 rows x 30 columns]
