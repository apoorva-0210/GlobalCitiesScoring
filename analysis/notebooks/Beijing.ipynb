# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('BeijingBuildings.csv',encoding='ISO-8859-1')
# Out:
# C:\Users\Apoorva\AppData\Local\Temp\ipykernel_680\1642353877.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('BeijingBuildings.csv',encoding='ISO-8859-1')

# %%
df
# Out:
#              name                        name_en building building_l  \
# 0             NaN                            NaN    house          2
# 1             NaN                            NaN    house          2
# 2             NaN                            NaN    house          2
# 3             NaN                            NaN    house          2
# 4             NaN                            NaN    house          2
# ...           ...                            ...      ...        ...
# 120089  ?????????  Fengtai Sports Center Stadium  stadium        NaN
# 120090        NaN                            NaN      yes        NaN
# 120091       48??                            NaN      yes         10
# 120092        NaN                            NaN      yes        NaN
# 120093        NaN                            NaN      yes        NaN
#
#         building_m addr_full addr_house addr_stree addr_city office  ... end  \
# 0              NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 1              NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 2              NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 3              NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 4              NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# ...            ...       ...        ...        ...       ...    ...  ...  ..
# 120089         NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 120090         NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 120091         NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 120092         NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
# 120093         NaN       NaN        NaN        NaN       NaN    NaN  ... NaN
#
#        altitudeMode  tessellate extrude  visibility  drawOrder icon      id  \
# 0               NaN          -1       0          -1        NaN  NaN  110108
# 1               NaN          -1       0          -1        NaN  NaN  110108
# 2               NaN          -1       0          -1        NaN  NaN  110108
# 3               NaN          -1       0          -1        NaN  NaN  110108
# 4               NaN          -1       0          -1        NaN  NaN  110108
# ...             ...         ...     ...         ...        ...  ...     ...
# 120089          NaN          -1       0          -1        NaN  NaN  110106
# 120090          NaN          -1       0          -1        NaN  NaN  110104
# 120091          NaN          -1       0          -1        NaN  NaN  110104
# 120092          NaN          -1       0          -1        NaN  NaN  110102
# 120093          NaN          -1       0          -1        NaN  NaN  110104
#
#                       cp  childNum
# 0       116.2202,40.0239         1
# 1       116.2202,40.0239         1
# 2       116.2202,40.0239         1
# 3       116.2202,40.0239         1
# 4       116.2202,40.0239         1
# ...                  ...       ...
# 120089  116.2683,39.8309         1
# 120090  116.3603,39.8852         1
# 120091  116.3603,39.8852         1
# 120092  116.3631,39.9353         1
# 120093  116.3603,39.8852         1
#
# [120094 rows x 30 columns]

# %%
set(list(df['building']))
# Out:
# {'apartments',
#  'barn',
#  'boathouse',
#  'bridge',
#  'bungalow',
#  'bunker',
#  'carport',
#  'chapel',
#  'church',
#  'civic',
#  'college',
#  'commercial',
#  'company',
#  'construction',
#  'cowshed',
#  'dam',
#  'depot',
#  'detached',
#  'dormitory',
#  'embassy',
#  'farm',
#  'farm_auxiliary',
#  'fire_station',
#  'garage',
#  'garages',
#  'gasometer',
#  'gate',
#  'ger',
#  'government',
#  'grandstand',
#  'greenhouse',
#  'gymnasium',
#  'hangar',
#  'hospital',
#  'hotel',
#  'hotel;yes',
#  'house',
#  'hut',
#  'industrial',
#  'kindergarten',
#  'library',
#  'military',
#  'mosque',
#  'museum',
#  'no',
#  'office',
#  'outbuilding',
#  'parking',
#  'pavilion',
#  'public',
#  'railway',
#  'railway_station',
#  'religious',
#  'research_institute',
#  'residential',
#  'restaurant',
#  'retail',
#  'roof',
#  'ruins',
#  'school',
#  'semidetached_house',
#  'service',
#  'shed',
#  'sheepfold',
#  'shrine',
#  'silo',
#  'sports_centre',
#  'stable',
#  'stadium',
#  'station',
#  'statue',
#  'storage_tank',
#  'sty',
#  'temple',
#  'temporary',
#  'terrace',
#  'toilets',
#  'toll_booth',
#  'tower',
#  'train_station',
#  'transportation',
#  'university',
#  'wall',
#  'warehouse',
#  'washroom',
#  'yes',
#  'yes;house',
#  'yes;school'}

# %%
df['name'] = df.index.map(lambda i: f'BeijingBuilding{i}')

# %%
df
# Out:
#                          name                        name_en building  \
# 0            BeijingBuilding0                            NaN    house
# 1            BeijingBuilding1                            NaN    house
# 2            BeijingBuilding2                            NaN    house
# 3            BeijingBuilding3                            NaN    house
# 4            BeijingBuilding4                            NaN    house
# ...                       ...                            ...      ...
# 120089  BeijingBuilding120089  Fengtai Sports Center Stadium  stadium
# 120090  BeijingBuilding120090                            NaN      yes
# 120091  BeijingBuilding120091                            NaN      yes
# 120092  BeijingBuilding120092                            NaN      yes
# 120093  BeijingBuilding120093                            NaN      yes
#
#        building_l  building_m addr_full addr_house addr_stree addr_city  \
# 0               2         NaN       NaN        NaN        NaN       NaN
# 1               2         NaN       NaN        NaN        NaN       NaN
# 2               2         NaN       NaN        NaN        NaN       NaN
# 3               2         NaN       NaN        NaN        NaN       NaN
# 4               2         NaN       NaN        NaN        NaN       NaN
# ...           ...         ...       ...        ...        ...       ...
# 120089        NaN         NaN       NaN        NaN        NaN       NaN
# 120090        NaN         NaN       NaN        NaN        NaN       NaN
# 120091         10         NaN       NaN        NaN        NaN       NaN
# 120092        NaN         NaN       NaN        NaN        NaN       NaN
# 120093        NaN         NaN       NaN        NaN        NaN       NaN
#
#        office  ... end altitudeMode  tessellate extrude  visibility  \
# 0         NaN  ... NaN          NaN          -1       0          -1
# 1         NaN  ... NaN          NaN          -1       0          -1
# 2         NaN  ... NaN          NaN          -1       0          -1
# 3         NaN  ... NaN          NaN          -1       0          -1
# 4         NaN  ... NaN          NaN          -1       0          -1
# ...       ...  ...  ..          ...         ...     ...         ...
# 120089    NaN  ... NaN          NaN          -1       0          -1
# 120090    NaN  ... NaN          NaN          -1       0          -1
# 120091    NaN  ... NaN          NaN          -1       0          -1
# 120092    NaN  ... NaN          NaN          -1       0          -1
# 120093    NaN  ... NaN          NaN          -1       0          -1
#
#         drawOrder icon      id                cp  childNum
# 0             NaN  NaN  110108  116.2202,40.0239         1
# 1             NaN  NaN  110108  116.2202,40.0239         1
# 2             NaN  NaN  110108  116.2202,40.0239         1
# 3             NaN  NaN  110108  116.2202,40.0239         1
# 4             NaN  NaN  110108  116.2202,40.0239         1
# ...           ...  ...     ...               ...       ...
# 120089        NaN  NaN  110106  116.2683,39.8309         1
# 120090        NaN  NaN  110104  116.3603,39.8852         1
# 120091        NaN  NaN  110104  116.3603,39.8852         1
# 120092        NaN  NaN  110102  116.3631,39.9353         1
# 120093        NaN  NaN  110104  116.3603,39.8852         1
#
# [120094 rows x 30 columns]

# %%
house = ['yes', 'apartments', 'residential', 'house', 'dormitory', 'bungalow', 'semidetached_house']
school = ['school', 'university', 'kindergarten', 'college']
public_transport = ['train_station', 'transportation']
hospital = ['hospital']

# %%
toilet = ['toilets']
civic = ['civic']
public = ['public']
fire = ['fire_station']
sports = ['grandstand', 'pavilion', 'riding_hall', 'sports_hall', 'sports_centre', 'stadium']
govt = ['government']
supermarket = ['supermarket']

df_toilet = df[df['building'].isin(toilet)]
df_civic = df[df['building'].isin(civic)]
df_public = df[df['building'].isin(public)]
df_fire = df[df['building'].isin(fire)]
df_sports = df[df['building'].isin(sports)]
df_govt = df[df['building'].isin(govt)]
df_supermarket = df[df['building'].isin(supermarket)]

df_toilet.to_csv('Toilet.csv', index = False)
df_civic.to_csv('Civic.csv', index = False)
df_public.to_csv('Public.csv', index = False)
df_fire.to_csv('Fire.csv', index = False)
df_sports.to_csv('Sports.csv', index = False)
df_govt.to_csv('Government.csv', index = False)
df_supermarket.to_csv('Supermarket.csv', index = False)

# %%
df_building = df[df['building'].isin(house)]
df_school = df[df['building'].isin(school)]
df_pt = df[df['building'].isin(public_transport)]
df_hospital = df[df['building'].isin(hospital)]

# %%
df_building.to_csv('BeijingBuildingsFinal.csv', index = False)
df_school.to_csv('School.csv', index = False)
df_pt.to_csv('Transport.csv', index = False)
df_hospital.to_csv('Hospital.csv', index = False)

# %%
df_civic
# Out:
#                        name name_en building building_l  building_m addr_full  \
# 23870  BeijingBuilding23870     NaN    civic          1         NaN       NaN
# 26541  BeijingBuilding26541     NaN    civic        NaN         NaN       NaN
# 34213  BeijingBuilding34213     NaN    civic        NaN         NaN       NaN
# 47638  BeijingBuilding47638     NaN    civic        NaN         NaN       NaN
# 47639  BeijingBuilding47639     NaN    civic        NaN         NaN       NaN
# 47640  BeijingBuilding47640     NaN    civic        NaN         NaN       NaN
# 65137  BeijingBuilding65137     NaN    civic        NaN         NaN       NaN
# 65138  BeijingBuilding65138     NaN    civic        NaN         NaN       NaN
#
#       addr_house addr_stree addr_city office  ... end altitudeMode  \
# 23870        NaN        NaN       NaN    NaN  ... NaN          NaN
# 26541        NaN        NaN       NaN    NaN  ... NaN          NaN
# 34213        NaN        NaN       NaN    NaN  ... NaN          NaN
# 47638        NaN        NaN       NaN    NaN  ... NaN          NaN
# 47639        NaN        NaN       NaN    NaN  ... NaN          NaN
# 47640        NaN        NaN       NaN    NaN  ... NaN          NaN
# 65137        NaN        NaN       NaN    NaN  ... NaN          NaN
# 65138        NaN        NaN       NaN    NaN  ... NaN          NaN
#
#        tessellate extrude  visibility  drawOrder icon      id  \
# 23870          -1       0          -1        NaN  NaN  110108
# 26541          -1       0          -1        NaN  NaN  110116
# 34213          -1       0          -1        NaN  NaN  110105
# 47638          -1       0          -1        NaN  NaN  110105
# 47639          -1       0          -1        NaN  NaN  110105
# 47640          -1       0          -1        NaN  NaN  110105
# 65137          -1       0          -1        NaN  NaN  110105
# 65138          -1       0          -1        NaN  NaN  110105
#
#                      cp  childNum
# 23870  116.2202,40.0239         1
# 26541  116.6377,40.6219         1
# 34213   116.4977,39.949         2
# 47638   116.4977,39.949         2
# 47639   116.4977,39.949         2
# 47640   116.4977,39.949         2
# 65137   116.4977,39.949         2
# 65138   116.4977,39.949         2
#
# [8 rows x 30 columns]
