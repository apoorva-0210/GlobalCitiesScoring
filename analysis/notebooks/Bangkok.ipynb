# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('BangkokBuildingV1.csv')
# Out:
# C:\Users\Apoorva\AppData\Local\Temp\ipykernel_13412\254613366.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('BangkokBuildingV1.csv')

# %%
for i in df.index:
    df['name'].iloc[i] = 'BangkokBuilding' + str(i)
# Out:
# C:\Users\Apoorva\AppData\Local\Temp\ipykernel_13412\1227371355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name'].iloc[i] = 'BangkokBuilding' + str(i)

# %%
df
# Out:
#                        name name_en building building_l  building_m  \
# 0          BangkokBuilding0     NaN      yes        NaN         NaN
# 1          BangkokBuilding1     NaN      yes        NaN         NaN
# 2          BangkokBuilding2     NaN      yes        NaN         NaN
# 3          BangkokBuilding3     NaN      yes        NaN         NaN
# 4          BangkokBuilding4     NaN      yes        NaN         NaN
# ...                     ...     ...      ...        ...         ...
# 40434  BangkokBuilding40434     NaN      yes        NaN         NaN
# 40435  BangkokBuilding40435     NaN      yes        NaN         NaN
# 40436  BangkokBuilding40436     NaN      yes        4.0         NaN
# 40437  BangkokBuilding40437     NaN      yes        4.0         NaN
# 40438  BangkokBuilding40438     NaN      yes        NaN         NaN
#
#        addr_full addr_house      addr_stree    addr_city office source  \
# 0            NaN        NaN             NaN          NaN    NaN    NaN
# ...

# %%
df['building'].value_counts()
# Out:
# yes                                 26818
# house                                7570
# residential                          3183
# apartments                            524
# terrace                               285
# temple                                279
# commercial                            272
# retail                                265
# school                                193
# roof                                  181
# industrial                            179
# university                            137
# hospital                               91
# office                                 64
# warehouse                              62
# dormitory                              53
# hotel                                  40
# semidetached_house                     36
# train_station                          29
# carport                                22
# detached                               18
# garage                                 17
# ...

# %%
df.rename(columns = {'Latitude' : 'lon', 'Longitude' : 'lat'}, inplace = True)

# %%
house = ['yes', 'apartments', 'residential', 'house', 'dormitory', 'bungalow', 'semidetached_house']
school = ['school', 'university', 'kindergarten', 'college']
public_transport = ['train_station', 'transportation']
hospital = ['hospital']

# %%
toilet = ['toilets']
civic = ['civic']
public = ['public']
fire = ['fire_station']
sports = ['grandstand', 'pavilion', 'riding_hall', 'sports_hall', 'sports_centre', 'stadium']
govt = ['government']
supermarket = ['supermarket']

df_toilet = df[df['building'].isin(toilet)]
df_civic = df[df['building'].isin(civic)]
df_public = df[df['building'].isin(public)]
df_fire = df[df['building'].isin(fire)]
df_sports = df[df['building'].isin(sports)]
df_govt = df[df['building'].isin(govt)]
df_supermarket = df[df['building'].isin(supermarket)]

# %%
df_toilet.to_csv('Toilet.csv', index = False)
df_civic.to_csv('Civic.csv', index = False)
df_public.to_csv('Public.csv', index = False)
df_fire.to_csv('Fire.csv', index = False)
df_sports.to_csv('Sports.csv', index = False)
df_govt.to_csv('Government.csv', index = False)
df_supermarket.to_csv('Supermarket.csv', index = False)

# %%
df_supermarket
# Out:
# Empty DataFrame
# Columns: [name, name_en, building, building_l, building_m, addr_full, addr_house, addr_stree, addr_city, office, source, name_th, osm_id, osm_type, lon, lat, source_2, id, name_2]
# Index: []

# %%
df_building = df[df['building'].isin(house)]
df_school = df[df['building'].isin(school)]
df_pt = df[df['building'].isin(public_transport)]
df_hospital = df[df['building'].isin(hospital)]

# %%
df_building.to_csv('BangkokBuildingsFinal.csv', index = False)
df_school.to_csv('School.csv', index = False)
df_pt.to_csv('Transport.csv', index = False)
df_hospital.to_csv('Hospital.csv', index = False)

# %%
df_hospital
