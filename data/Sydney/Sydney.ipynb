# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('SydneyBuildings.csv')
# Out:
# C:\Users\Apoorva\AppData\Local\Temp\ipykernel_18508\3236017265.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SydneyBuildings.csv')

# %%
df['building'].value_counts()
# Out:
# house           129511
# yes             115562
# detached         12914
# apartments       10128
# garage            8790
#                  ...
# motel                1
# corridor             1
# garage;house         1
# club_house           1
# yes;retail           1
# Name: building, Length: 142, dtype: int64

# %%
df
# Out:
#                             name                   name_en     building  \
# 0                            NaN                       NaN  residential
# 1                  Warners Court                       NaN  residential
# 2                            NaN                       NaN      toilets
# 3                        El Nido                       NaN  residential
# 4                            NaN                       NaN  residential
# ...                          ...                       ...          ...
# 315927                       NaN                       NaN       stable
# 315928                       NaN                       NaN          yes
# 315929  SEA LIFE Sydney Aquarium  SEA LIFE Sydney Aquarium          yes
# 315930  SEA LIFE Sydney Aquarium  SEA LIFE Sydney Aquarium          yes
# 315931                       NaN                       NaN   apartments
#
#        building_l  building_m addr_full addr_house           addr_stree  \
# 0             NaN         NaN       NaN        102       Warners Avenue
# 1             NaN         NaN       NaN        100       Warners Avenue
# 2               1         NaN       NaN        NaN                  NaN
# 3             NaN         NaN       NaN          7      Ramsgate Avenue
# 4             NaN         NaN       NaN        106       Warners Avenue
# ...           ...         ...       ...        ...                  ...
# 315927        NaN         NaN       NaN        NaN                  NaN
# 315928        NaN         NaN       NaN        NaN                  NaN
# 315929          1         NaN       NaN        1-5  King Street Offramp
# 315930          1         NaN       NaN        1-5  King Street Offramp
# 315931          9         NaN       NaN        NaN                  NaN
#
#        addr_city office  ...      osm_id   osm_type   fid  admin_leve  name_2  \
# 0            NaN    NaN  ...   789124467  ways_poly   578           7  Sydney
# 1            NaN    NaN  ...   789124468  ways_poly   578           7  Sydney
# 2            NaN    NaN  ...  1028285389  ways_poly   578           7  Sydney
# 3            NaN    NaN  ...   789124460  ways_poly   578           7  Sydney
# 4            NaN    NaN  ...   789124465  ways_poly   578           7  Sydney
# ...          ...    ...  ...         ...        ...   ...         ...     ...
# 315927       NaN    NaN  ...    17588950  relations   578           7  Sydney
# 315928       NaN    NaN  ...    17582748  relations   578           7  Sydney
# 315929       NaN    NaN  ...    18224617  relations   578           7  Sydney
# 315930       NaN    NaN  ...    18224617  relations  2495          11  Sydney
# 315931       NaN    NaN  ...     7929410  relations   578           7  Sydney
#
#        name_en_2  population  hasc         lon        lat
# 0            NaN   4473131.0   NaN  151.276139 -33.887111
# 1            NaN   4473131.0   NaN  151.275991 -33.886996
# 2            NaN   4473131.0   NaN  151.211334 -33.831097
# 3            NaN   4473131.0   NaN  151.276469 -33.886943
# 4            NaN   4473131.0   NaN  151.276354 -33.887269
# ...          ...         ...   ...         ...        ...
# 315927       NaN   4473131.0   NaN  151.023598 -33.825699
# 315928       NaN   4473131.0   NaN  151.218831 -33.722851
# 315929       NaN   4473131.0   NaN  151.202148 -33.869618
# 315930       NaN     22109.0   NaN  151.202148 -33.869618
# 315931       NaN   4473131.0   NaN  151.215730 -33.849217
#
# [315932 rows x 21 columns]

# %%
df['name'] = df.index.map(lambda i: f'SydneyBuilding{i}')

# %%
df
# Out:
#                         name                   name_en     building  \
# 0            SydneyBuilding0                       NaN  residential
# 1            SydneyBuilding1                       NaN  residential
# 2            SydneyBuilding2                       NaN      toilets
# 3            SydneyBuilding3                       NaN  residential
# 4            SydneyBuilding4                       NaN  residential
# ...                      ...                       ...          ...
# 315927  SydneyBuilding315927                       NaN       stable
# 315928  SydneyBuilding315928                       NaN          yes
# 315929  SydneyBuilding315929  SEA LIFE Sydney Aquarium          yes
# 315930  SydneyBuilding315930  SEA LIFE Sydney Aquarium          yes
# 315931  SydneyBuilding315931                       NaN   apartments
#
#        building_l  building_m addr_full addr_house           addr_stree  \
# 0             NaN         NaN       NaN        102       Warners Avenue
# 1             NaN         NaN       NaN        100       Warners Avenue
# 2               1         NaN       NaN        NaN                  NaN
# 3             NaN         NaN       NaN          7      Ramsgate Avenue
# 4             NaN         NaN       NaN        106       Warners Avenue
# ...           ...         ...       ...        ...                  ...
# 315927        NaN         NaN       NaN        NaN                  NaN
# 315928        NaN         NaN       NaN        NaN                  NaN
# 315929          1         NaN       NaN        1-5  King Street Offramp
# 315930          1         NaN       NaN        1-5  King Street Offramp
# 315931          9         NaN       NaN        NaN                  NaN
#
#        addr_city office  ...      osm_id   osm_type   fid  admin_leve  name_2  \
# 0            NaN    NaN  ...   789124467  ways_poly   578           7  Sydney
# 1            NaN    NaN  ...   789124468  ways_poly   578           7  Sydney
# 2            NaN    NaN  ...  1028285389  ways_poly   578           7  Sydney
# 3            NaN    NaN  ...   789124460  ways_poly   578           7  Sydney
# 4            NaN    NaN  ...   789124465  ways_poly   578           7  Sydney
# ...          ...    ...  ...         ...        ...   ...         ...     ...
# 315927       NaN    NaN  ...    17588950  relations   578           7  Sydney
# 315928       NaN    NaN  ...    17582748  relations   578           7  Sydney
# 315929       NaN    NaN  ...    18224617  relations   578           7  Sydney
# 315930       NaN    NaN  ...    18224617  relations  2495          11  Sydney
# 315931       NaN    NaN  ...     7929410  relations   578           7  Sydney
#
#        name_en_2  population  hasc         lon        lat
# 0            NaN   4473131.0   NaN  151.276139 -33.887111
# 1            NaN   4473131.0   NaN  151.275991 -33.886996
# 2            NaN   4473131.0   NaN  151.211334 -33.831097
# 3            NaN   4473131.0   NaN  151.276469 -33.886943
# 4            NaN   4473131.0   NaN  151.276354 -33.887269
# ...          ...         ...   ...         ...        ...
# 315927       NaN   4473131.0   NaN  151.023598 -33.825699
# 315928       NaN   4473131.0   NaN  151.218831 -33.722851
# 315929       NaN   4473131.0   NaN  151.202148 -33.869618
# 315930       NaN     22109.0   NaN  151.202148 -33.869618
# 315931       NaN   4473131.0   NaN  151.215730 -33.849217
#
# [315932 rows x 21 columns]

# %%
house = ['yes', 'apartments', 'residential', 'house', 'dormitory', 'bungalow', 'semidetached_house']
school = ['school', 'university', 'kindergarten', 'college']
public_transport = ['train_station', 'transportation']
hospital = ['hospital']

# %%
df_building = df[df['building'].isin(house)]
df_school = df[df['building'].isin(school)]
df_pt = df[df['building'].isin(public_transport)]
df_hospital = df[df['building'].isin(hospital)]

# %%
toilet = ['toilets']
civic = ['civic']
public = ['public']
fire = ['fire_station']
sports = ['grandstand', 'pavilion', 'riding_hall', 'sports_hall', 'sports_centre', 'stadium']
govt = ['government']
supermarket = ['supermarket']

df_toilet = df[df['building'].isin(toilet)]
df_civic = df[df['building'].isin(civic)]
df_public = df[df['building'].isin(public)]
df_fire = df[df['building'].isin(fire)]
df_sports = df[df['building'].isin(sports)]
df_govt = df[df['building'].isin(govt)]
df_supermarket = df[df['building'].isin(supermarket)]

df_toilet.to_csv('Toilet.csv', index = False)
df_civic.to_csv('Civic.csv', index = False)
df_public.to_csv('Public.csv', index = False)
df_fire.to_csv('Fire.csv', index = False)
df_sports.to_csv('Sports.csv', index = False)
df_govt.to_csv('Government.csv', index = False)
df_supermarket.to_csv('Supermarket.csv', index = False)

# %%
df_building.to_csv('SydneyBuildingsFinal.csv', index = False)
df_school.to_csv('School.csv', index = False)
df_pt.to_csv('Transport.csv', index = False)
df_hospital.to_csv('Hospital.csv', index = False)

# %%
df_public
# Out:
#                         name name_en building building_l  building_m  \
# 1523      SydneyBuilding1523     NaN   public        NaN         NaN
# 2795      SydneyBuilding2795     NaN   public          1         NaN
# 25238    SydneyBuilding25238     NaN   public          3         NaN
# 67877    SydneyBuilding67877     NaN   public          2         NaN
# 68315    SydneyBuilding68315     NaN   public          7         NaN
# 68316    SydneyBuilding68316     NaN   public          7         NaN
# 82915    SydneyBuilding82915     NaN   public          1         NaN
# 84921    SydneyBuilding84921     NaN   public          2         NaN
# 91315    SydneyBuilding91315     NaN   public        NaN         NaN
# 100867  SydneyBuilding100867     NaN   public          1         NaN
# 126492  SydneyBuilding126492     NaN   public          4         NaN
# 126493  SydneyBuilding126493     NaN   public          4         NaN
# 129863  SydneyBuilding129863     NaN   public          1         NaN
# 129864  SydneyBuilding129864     NaN   public          1         NaN
# 130061  SydneyBuilding130061     NaN   public        NaN         NaN
# 130769  SydneyBuilding130769     NaN   public        NaN         NaN
# 130829  SydneyBuilding130829     NaN   public          2         NaN
# 131256  SydneyBuilding131256     NaN   public        NaN         NaN
# 131377  SydneyBuilding131377     NaN   public        NaN         NaN
# 131470  SydneyBuilding131470     NaN   public          3         NaN
# 132724  SydneyBuilding132724     NaN   public          3         NaN
# 133814  SydneyBuilding133814     NaN   public        NaN         NaN
# 161122  SydneyBuilding161122     NaN   public          2         NaN
# 163297  SydneyBuilding163297     NaN   public          2         NaN
# 201206  SydneyBuilding201206     NaN   public        NaN         NaN
# 202774  SydneyBuilding202774     NaN   public          1         NaN
# 206480  SydneyBuilding206480     NaN   public        NaN         NaN
# 219321  SydneyBuilding219321     NaN   public          3         NaN
# 229303  SydneyBuilding229303     NaN   public        NaN         NaN
# 231479  SydneyBuilding231479     NaN   public        NaN         NaN
# 233784  SydneyBuilding233784     NaN   public        NaN         NaN
# 234173  SydneyBuilding234173     NaN   public         11         NaN
# 234174  SydneyBuilding234174     NaN   public          2         NaN
# 234189  SydneyBuilding234189     NaN   public         12         NaN
# 237873  SydneyBuilding237873     NaN   public          2         NaN
# 241386  SydneyBuilding241386     NaN   public         15         NaN
# 241389  SydneyBuilding241389     NaN   public          5         NaN
# 254767  SydneyBuilding254767     NaN   public        NaN         NaN
# 257364  SydneyBuilding257364     NaN   public        NaN         NaN
# 258375  SydneyBuilding258375     NaN   public        NaN         NaN
# 262169  SydneyBuilding262169     NaN   public        NaN         NaN
# 266661  SydneyBuilding266661     NaN   public        NaN         NaN
# 271656  SydneyBuilding271656     NaN   public        NaN         NaN
# 272187  SydneyBuilding272187     NaN   public        NaN         NaN
# 301501  SydneyBuilding301501     NaN   public        NaN         NaN
# 310318  SydneyBuilding310318     NaN   public          6         NaN
# 310775  SydneyBuilding310775     NaN   public          4         NaN
#
#        addr_full addr_house          addr_stree         addr_city      office  \
# 1523         NaN        725      Pittwater Road               NaN         NaN
# 2795         NaN        NaN                 NaN               NaN         NaN
# 25238        NaN        NaN                 NaN               NaN         NaN
# 67877        NaN        NaN                 NaN        Warriewood         NaN
# 68315        NaN        NaN    Macquarie Street               NaN         NaN
# 68316        NaN        NaN    Macquarie Street               NaN         NaN
# 82915        NaN        NaN                 NaN               NaN         NaN
# 84921        NaN        NaN                 NaN               NaN         NaN
# 91315        NaN        NaN                 NaN               NaN         NaN
# 100867       NaN        NaN                 NaN               NaN         NaN
# 126492       NaN          1  Prince Albert Road               NaN         NaN
# 126493       NaN          1  Prince Albert Road               NaN         NaN
# 129863       NaN        NaN                 NaN               NaN         NaN
# 129864       NaN          6       Jacksons Road        Warriewood         NaN
# 130061       NaN        NaN                 NaN               NaN         NaN
# 130769       NaN        NaN                 NaN               NaN         NaN
# 130829       NaN        725      Pittwater Road               NaN         NaN
# 131256       NaN        NaN                 NaN               NaN         NaN
# 131377       NaN        NaN                 NaN               NaN         NaN
# 131470       NaN        NaN                 NaN               NaN         NaN
# 132724       NaN        NaN                 NaN               NaN         NaN
# 133814       NaN        NaN                 NaN               NaN         NaN
# 161122       NaN       4-20                 NaN               NaN  government
# 163297       NaN         30     Shoreline Drive               NaN         NaN
# 201206       NaN        NaN                 NaN               NaN         NaN
# 202774       NaN        NaN                 NaN               NaN         NaN
# 206480       NaN        NaN                 NaN               NaN         NaN
# 219321       NaN        NaN                 NaN               NaN         NaN
# 229303       NaN          7                 NaN               NaN         NaN
# 231479       NaN         86          Avoca Road               NaN  government
# 233784       NaN        NaN                 NaN               NaN         NaN
# 234173       NaN        NaN                 NaN               NaN         NaN
# 234174       NaN          4       George Street               NaN         NaN
# 234189       NaN      97-99     Goulburn Street               NaN         NaN
# 237873       NaN      77-79    Doncaster Avenue               NaN         NaN
# 241386       NaN          1      Charles Street               NaN         NaN
# 241389       NaN        160          Marsden st               NaN         NaN
# 254767       NaN         40            Kingsway               NaN         NaN
# 257364       NaN        NaN                 NaN               NaN         NaN
# 258375       NaN        NaN                 NaN               NaN         NaN
# 262169       NaN       1423         Botany Road               NaN         NaN
# 266661       NaN        NaN                 NaN               NaN         NaN
# 271656       NaN        NaN                 NaN               NaN         NaN
# 272187       NaN         65        Queen Street               NaN         NaN
# 301501       NaN         34    Blandford Street  Collaroy Plateau         NaN
# 310318       NaN          6       George Street               NaN         NaN
# 310775       NaN         22       George Street        Parramatta         NaN
#
#         ...      osm_id   osm_type   fid  admin_leve  name_2 name_en_2  \
# 1523    ...   718895616  ways_poly   578           7  Sydney       NaN
# 2795    ...   687897770  ways_poly   578           7  Sydney       NaN
# 25238   ...   562120201  ways_poly   578           7  Sydney       NaN
# 67877   ...   828439266  ways_poly   578           7  Sydney       NaN
# 68315   ...    16750157  ways_poly   578           7  Sydney       NaN
# 68316   ...    16750157  ways_poly  2495          11  Sydney       NaN
# 82915   ...   378237289  ways_poly   578           7  Sydney       NaN
# 84921   ...   271380482  ways_poly   578           7  Sydney       NaN
# 91315   ...   780167104  ways_poly   578           7  Sydney       NaN
# 100867  ...   838521406  ways_poly   578           7  Sydney       NaN
# 126492  ...    16750415  ways_poly   578           7  Sydney       NaN
# 126493  ...    16750415  ways_poly  2495          11  Sydney       NaN
# 129863  ...   827621553  ways_poly   578           7  Sydney       NaN
# 129864  ...   827621554  ways_poly   578           7  Sydney       NaN
# 130061  ...   399352578  ways_poly   578           7  Sydney       NaN
# 130769  ...   234341578  ways_poly   578           7  Sydney       NaN
# 130829  ...   718895617  ways_poly   578           7  Sydney       NaN
# 131256  ...   841676609  ways_poly   578           7  Sydney       NaN
# 131377  ...    31228778  ways_poly   578           7  Sydney       NaN
# 131470  ...   473980567  ways_poly   578           7  Sydney       NaN
# 132724  ...   562120196  ways_poly   578           7  Sydney       NaN
# 133814  ...   841676610  ways_poly   578           7  Sydney       NaN
# 161122  ...   393286716  ways_poly   578           7  Sydney       NaN
# 163297  ...   508150229  ways_poly   578           7  Sydney       NaN
# 201206  ...  1031110715  ways_poly   578           7  Sydney       NaN
# 202774  ...   169219244  ways_poly   578           7  Sydney       NaN
# 206480  ...   756406630  ways_poly   578           7  Sydney       NaN
# 219321  ...   219238035  ways_poly   578           7  Sydney       NaN
# 229303  ...  1338566678  ways_poly   578           7  Sydney       NaN
# 231479  ...   285367798  ways_poly   578           7  Sydney       NaN
# 233784  ...  1127931545  ways_poly   578           7  Sydney       NaN
# 234173  ...   562120199  ways_poly   578           7  Sydney       NaN
# 234174  ...   562120200  ways_poly   578           7  Sydney       NaN
# 234189  ...   232516681  ways_poly   578           7  Sydney       NaN
# 237873  ...   682800158  ways_poly   578           7  Sydney       NaN
# 241386  ...    69343617  ways_poly   578           7  Sydney       NaN
# 241389  ...   151559644  ways_poly   578           7  Sydney       NaN
# 254767  ...   718895619  ways_poly   578           7  Sydney       NaN
# 257364  ...   223784846  ways_poly   578           7  Sydney       NaN
# 258375  ...   839852003  ways_poly   578           7  Sydney       NaN
# 262169  ...  1258912387  ways_poly   578           7  Sydney       NaN
# 266661  ...   769620606  ways_poly   578           7  Sydney       NaN
# 271656  ...  1186469482  ways_poly   578           7  Sydney       NaN
# 272187  ...   183242184  ways_poly   578           7  Sydney       NaN
# 301501  ...   360339174  ways_poly   578           7  Sydney       NaN
# 310318  ...   562120198  ways_poly   578           7  Sydney       NaN
# 310775  ...   562111453  ways_poly   578           7  Sydney       NaN
#
#         population  hasc         lon        lat
# 1523     4473131.0   NaN  151.287029 -33.751324
# 2795     4473131.0   NaN  150.373474 -33.709229
# 25238    4473131.0   NaN  151.000855 -33.812556
# 67877    4473131.0   NaN  151.298622 -33.697167
# 68315    4473131.0   NaN  151.213038 -33.867348
# 68316      22109.0   NaN  151.213038 -33.867348
# 82915    4473131.0   NaN  151.270001 -33.717503
# 84921    4473131.0   NaN  151.225563 -33.873117
# 91315    4473131.0   NaN  151.291338 -33.729416
# 100867   4473131.0   NaN  151.300157 -33.694362
# 126492   4473131.0   NaN  151.213307 -33.869996
# 126493     22109.0   NaN  151.213307 -33.869996
# 129863   4473131.0   NaN  151.300191 -33.697301
# 129864   4473131.0   NaN  151.299667 -33.697175
# 130061   4473131.0   NaN  151.264332 -33.718548
# 130769   4473131.0   NaN  151.282119 -33.795656
# 130829   4473131.0   NaN  151.286586 -33.751713
# 131256   4473131.0   NaN  151.220144 -33.741357
# 131377   4473131.0   NaN  151.215792 -33.833292
# 131470   4473131.0   NaN  151.234894 -33.756856
# 132724   4473131.0   NaN  151.002218 -33.812619
# 133814   4473131.0   NaN  151.219831 -33.741334
# 161122   4473131.0   NaN  151.059788 -34.030549
# 163297   4473131.0   NaN  151.083474 -33.829091
# 201206   4473131.0   NaN  150.751980 -33.708478
# 202774   4473131.0   NaN  151.191351 -33.889004
# 206480   4473131.0   NaN  151.206700 -33.899367
# 219321   4473131.0   NaN  151.002701 -33.812883
# 229303   4473131.0   NaN  151.182983 -33.799238
# 231479   4473131.0   NaN  150.914920 -33.878721
# 233784   4473131.0   NaN  151.207013 -33.899377
# 234173   4473131.0   NaN  151.001586 -33.812253
# 234174   4473131.0   NaN  151.001437 -33.812819
# 234189   4473131.0   NaN  151.208259 -33.878542
# 237873   4473131.0   NaN  151.225040 -33.909449
# 241386   4473131.0   NaN  151.007980 -33.817332
# 241389   4473131.0   NaN  151.002242 -33.811737
# 254767   4473131.0   NaN  151.286215 -33.750324
# 257364   4473131.0   NaN  151.285983 -33.797610
# 258375   4473131.0   NaN  151.304095 -33.676209
# 262169   4473131.0   NaN  151.197178 -33.945224
# 266661   4473131.0   NaN  151.238560 -33.825075
# 271656   4473131.0   NaN  151.124303 -33.889025
# 272187   4473131.0   NaN  150.817210 -34.062545
# 301501   4473131.0   NaN  151.291414 -33.729567
# 310318   4473131.0   NaN  151.001953 -33.812552
# 310775   4473131.0   NaN  151.000672 -33.813316
#
# [47 rows x 21 columns]
