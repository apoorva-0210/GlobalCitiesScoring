# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from geopy.geocoders import Nominatim
from math import radians, cos, sin, asin, sqrt
from numpy import cos, sin, arcsin, sqrt
from ast import literal_eval
from tqdm import tqdm
import requests
import json
import networkx as nx
import osmnx as ox
import requests
from geopy import Point
from geopy.distance import geodesic
import numpy as np

# %%
df_building = pd.read_csv('IstanbulBuildingsFinal.csv')

# %%
df_building.rename(columns={'name' : 'Building'}, inplace = True)

# %%
df_civic = pd.read_csv('CivicDistance.csv')
df_fire = pd.read_csv('FireDistance.csv')
df_government = pd.read_csv('GovernmentDistance.csv')
df_hospital = pd.read_csv('HospitalDistance.csv')
df_public = pd.read_csv('PublicDistance.csv')
df_school = pd.read_csv('SchoolDistance.csv')
df_sports = pd.read_csv('SportsDistance.csv')
df_supermarket = pd.read_csv('SupermarketDistance.csv')
df_toilet = pd.read_csv('ToiletDistance.csv')
df_transport = pd.read_csv('TransportDistance.csv')

# %%
df_civic = df_civic.groupby('InputID').agg(lambda x: list(x))
df_fire = df_fire.groupby('InputID').agg(lambda x: list(x))
df_government = df_government.groupby('InputID').agg(lambda x: list(x))
df_hospital = df_hospital.groupby('InputID').agg(lambda x: list(x))
df_public = df_public.groupby('InputID').agg(lambda x: list(x))
df_school = df_school.groupby('InputID').agg(lambda x: list(x))
df_sports = df_sports.groupby('InputID').agg(lambda x: list(x))
df_supermarket = df_supermarket.groupby('InputID').agg(lambda x: list(x))
df_toilet = df_toilet.groupby('InputID').agg(lambda x: list(x))
df_transport = df_transport.groupby('InputID').agg(lambda x: list(x))

# %%
df_civic = df_civic.reset_index()
df_fire = df_fire.reset_index()
df_government = df_government.reset_index()
df_hospital = df_hospital.reset_index()
df_public = df_public.reset_index()
df_school = df_school.reset_index()
df_sports = df_sports.reset_index()
df_supermarket = df_supermarket.reset_index()
df_toilet = df_toilet.reset_index()
df_transport = df_transport.reset_index()

# %%
df_civic.drop(columns=['TargetID'], inplace = True)
df_fire.drop(columns=['TargetID'], inplace = True)
df_government.drop(columns=['TargetID'], inplace = True)
df_hospital.drop(columns=['TargetID'], inplace = True)
df_public.drop(columns=['TargetID'], inplace = True)
df_school.drop(columns=['TargetID'], inplace = True)
df_sports.drop(columns=['TargetID'], inplace = True)
df_supermarket.drop(columns=['TargetID'], inplace = True)
df_toilet.drop(columns=['TargetID'], inplace = True)
df_transport.drop(columns=['TargetID'], inplace = True)

# %%
df_civic
df_fire
df_government
df_hospital
df_public
df_school
df_sports
df_supermarket
df_toilet
df_transport
# Out:
#                       InputID  \
# 0           IstanbulBuilding0
# 1           IstanbulBuilding1
# 2          IstanbulBuilding10
# 3         IstanbulBuilding100
# 4        IstanbulBuilding1000
# ...                       ...
# 594630  IstanbulBuilding99995
# 594631  IstanbulBuilding99996
# 594632  IstanbulBuilding99997
# 594633  IstanbulBuilding99998
# 594634  IstanbulBuilding99999
#
#                                                  Distance
# 0       [635.261039442742, 587.88351950614, 398.080163...
# 1       [721.195093066016, 196.239079252915, 203.93087...
# 2       [618.596525964286, 833.531524482347, 1914.1557...
# 3       [474.861297684743, 2780.37009270421, 1390.3424...
# 4       [1591.88253780387, 1563.04331090258, 541.39412...
# ...                                                   ...
# 594630  [1404.8571341282, 1736.77605558707, 1811.35242...
# 594631  [1446.20428769677, 2288.53522122854, 2342.8897...
# 594632  [1489.18909737521, 2235.82159850062, 2288.4953...
# 594633  [1442.24467163801, 2403.55075282339, 1815.7381...
# 594634  [1444.98372156985, 2242.40760964614, 2296.2215...
#
# [594635 rows x 2 columns]

# %%
df_civic.rename(columns={'InputID':'Building', 'Distance':'Civic'}, inplace = True)
df_fire.rename(columns={'InputID':'Building', 'Distance':'Fire'}, inplace = True)
df_government.rename(columns={'InputID':'Building', 'Distance':'Government'}, inplace = True)
df_hospital.rename(columns={'InputID':'Building', 'Distance':'Hospital'}, inplace = True)
df_public.rename(columns={'InputID':'Building', 'Distance':'Public'}, inplace = True)
df_school.rename(columns={'InputID':'Building', 'Distance':'School'}, inplace = True)
df_sports.rename(columns={'InputID':'Building', 'Distance':'Sports'}, inplace = True)
df_supermarket.rename(columns={'InputID':'Building', 'Distance':'Supermarket'}, inplace = True)
df_toilet.rename(columns={'InputID':'Building', 'Distance':'Toilet'}, inplace = True)
df_transport.rename(columns={'InputID':'Building', 'Distance':'Transport'}, inplace = True)

# %%
df = df_building.merge(df_civic, on='Building', how = 'inner')
df = df.merge(df_fire, on='Building', how = 'inner')
df = df.merge(df_government, on='Building', how = 'inner')
df = df.merge(df_hospital, on='Building', how = 'inner')
df = df.merge(df_public, on='Building', how = 'inner')
df = df.merge(df_school, on='Building', how = 'inner')
df = df.merge(df_sports, on='Building', how = 'inner')
df = df.merge(df_supermarket, on='Building', how = 'inner')
df = df.merge(df_toilet, on='Building', how = 'inner')
df = df.merge(df_transport, on='Building', how = 'inner')

# %%
df
# Out:
#                       Building name_en building building_l  building_m  \
# 0            IstanbulBuilding0     NaN      yes        NaN         NaN
# 1            IstanbulBuilding1     NaN      yes        NaN         NaN
# 2            IstanbulBuilding2     NaN      yes        NaN         NaN
# 3            IstanbulBuilding3     NaN      yes        NaN         NaN
# 4            IstanbulBuilding4     NaN      yes        NaN         NaN
# ...                        ...     ...      ...        ...         ...
# 246332  IstanbulBuilding259781     NaN      yes        NaN         NaN
# 246333  IstanbulBuilding259782     NaN      yes        NaN         NaN
# 246334  IstanbulBuilding259783     NaN      yes        NaN         NaN
# 246335  IstanbulBuilding259784     NaN      yes        NaN         NaN
# 246336  IstanbulBuilding259785     NaN      yes        NaN         NaN
#
#        addr_full addr_house addr_stree addr_city office  ...  \
# 0            NaN        NaN        NaN       NaN    NaN  ...
# 1            NaN        NaN        NaN       NaN    NaN  ...
# 2            NaN        NaN        NaN       NaN    NaN  ...
# 3            NaN        NaN        NaN       NaN    NaN  ...
# 4            NaN        NaN        NaN       NaN    NaN  ...
# ...          ...        ...        ...       ...    ...  ...
# 246332       NaN        NaN        NaN       NaN    NaN  ...
# 246333       NaN        NaN        NaN       NaN    NaN  ...
# 246334       NaN        NaN        NaN       NaN    NaN  ...
# 246335       NaN        NaN        NaN       NaN    NaN  ...
# 246336       NaN        NaN        NaN       NaN    NaN  ...
#
#                                                     Civic                Fire  \
# 0       [5142.90513566727, 2204.05449499053, 942.66960...  [12630.6250548564]
# 1       [5318.41388541644, 2489.5430048923, 1209.07332...  [12783.4874813717]
# 2       [5364.41379332222, 1479.53133141622, 194.20148...  [12870.9686544224]
# 3       [5311.63829635009, 2419.27338273401, 1138.6577...  [12783.2494253463]
# 4       [3238.36455013936, 7563.36176847748, 5712.0747...  [5677.57656318287]
# ...                                                   ...                 ...
# 246332  [424.717371999632, 1499.5479512655, 3965.84571...  [12470.0155683353]
# 246333  [416.188424196078, 1475.7016700807, 3941.12590...  [12467.9908068325]
# 246334  [400.005024641999, 1461.42134003253, 3931.1730...  [12480.4809229949]
# 246335  [408.374034074145, 1462.42467834251, 3928.8659...  [12471.1245367345]
# 246336  [409.671020770881, 1503.69218787892, 3977.3461...  [12491.2788585192]
#
#                                                Government  \
# 0       [265.008061624614, 798.687991485854, 398.45494...
# 1       [582.43838221902, 1065.94578773132, 306.556503...
# 2       [566.879069297286, 77.66207683595, 311.3248772...
# 3       [518.835568383839, 995.531664737983, 266.94409...
# 4       [1738.91719955921, 4667.60144865837, 7553.9568...
# ...                                                   ...
# 246332  [1626.49624570421, 1159.33322609724, 1994.3325...
# 246333  [1602.37286821299, 1135.0220768518, 1970.12976...
# 246334  [1588.54978949188, 1126.96403890584, 1956.4572...
# 246335  [1589.13265950805, 1123.4962114718, 1956.90741...
# 246336  [1631.60325095121, 1173.18208182775, 1999.7196...
#
#                                                  Hospital  \
# 0       [532.872335019584, 1711.91041900524, 1633.1512...
# 1       [852.716725732261, 2031.64396538352, 1350.0596...
# 2       [514.861123114354, 1316.88883563397, 1311.9354...
# 3       [790.753937962783, 1971.69706262167, 1420.4355...
# 4       [1712.03621431289, 836.337045562986, 1721.1689...
# ...                                                   ...
# 246332  [979.762952462191, 894.581597725917, 932.64004...
# 246333  [959.886437505913, 875.856468981261, 912.62731...
# 246334  [959.345892972254, 876.644803280662, 911.93934...
# 246335  [952.401378373406, 869.232240106061, 905.04709...
# 246336  [999.949314532845, 915.477651614047, 952.72871...
#
#                                                    Public  \
# 0       [334.223782590917, 1082.61890651731, 722.95967...
# 1       [171.726425463782, 1347.51014055265, 771.65630...
# 2       [914.653535114915, 979.875931867795, 98.326423...
# 3       [138.185924256026, 1414.36397713912, 840.52839...
# 4       [2361.30869550913, 2339.16279457851, 2835.6913...
# ...                                                   ...
# 246332  [2581.31870264479, 1295.56415420577, 683.20292...
# 246333  [2556.82699299051, 1279.75105637683, 675.66199...
# 246334  [2543.85409924245, 1262.37425691639, 685.49181...
# 246335  [2543.7140451935, 1268.57207762417, 676.147345...
# 246336  [1286.41326173086, 705.816350131795, 1689.1203...
#
#                                                    School  \
# 0       [440.047223464837, 95.5748590685273, 392.30415...
# 1       [758.097480910551, 410.000415519552, 582.85938...
# 2       [304.792223756657, 450.541042338742, 265.96280...
# 3       [700.587274098884, 346.681649624954, 513.80680...
# 4       [544.103720032261, 527.823220116309, 553.60682...
# ...                                                   ...
# 246332  [61.5500591147932, 79.7051975628483, 711.28050...
# 246333  [80.3052629514267, 59.9974892466217, 697.81050...
# 246334  [97.1347742447634, 63.7860241078799, 703.51574...
# 246335  [93.126080089714, 55.0873326635276, 694.756557...
# 246336               [73.2308097231555, 99.6496037575457]
#
#                                                    Sports  \
# 0       [1002.13684865337, 1070.01990063315, 1036.1185...
# 1       [1201.20550208683, 1242.52580610666, 1208.2666...
# 2       [316.010482586767, 434.649834970953, 411.57805...
# 3       [1133.85169483486, 1177.58540906788, 1143.2763...
# 4       [3624.52322243564, 2433.26425391115, 3435.9576...
# ...                                                   ...
# 246332  [1704.27267597839, 1776.09615058402, 1693.6160...
# 246333  [1681.90572841109, 1754.4181196178, 1714.42902...
# 246334  [1666.14936179323, 1738.24288334567, 1754.4963...
# 246335  [1668.7330916048, 1741.37626213664, 1757.47568...
# 246336  [1704.59500200062, 1775.03738864002, 1696.6764...
#
#                                               Supermarket  \
# 0       [19966.4862359231, 19989.1960509538, 16503.138...
# 1       [20132.3056237067, 20156.8921186994, 16453.395...
# 2       [20161.7907569297, 20179.3735793746, 17130.430...
# 3       [20129.0070680966, 20153.1127827301, 16496.067...
# 4       [12974.9559290269, 13044.5270183349, 13023.016...
# ...                                                   ...
# 246332  [19605.7447435161, 19612.1498185429, 17732.195...
# 246333  [19606.6981901334, 19613.2797155538, 17716.901...
# 246334  [19620.5410846014, 19627.1970508366, 17720.669...
# 246335  [19611.350997164, 19618.0210438654, 17712.4007...
# 246336  [19625.8689855581, 19632.1975070308, 17754.454...
#
#                                                    Toilet  \
# 0       [2296.58736834653, 24263.820923906, 21065.5804...
# 1       [2616.29746801393, 24221.9719411727, 20827.730...
# 2       [1797.03667081676, 24876.6924256517, 21130.664...
# 3       [2553.39722102633, 24263.379207507, 20850.6444...
# 4       [7567.34770162942, 17333.3654070128, 27589.199...
# ...                                                   ...
# 246332  [642.682314170713, 25400.1621300375, 22321.883...
# 246333  [636.340148572854, 25386.1081160745, 22308.893...
# 246334  [646.900959642187, 25390.9162755521, 22291.680...
# 246335  [637.518973587302, 25382.3888746734, 22298.745...
# 246336  [665.136531497885, 25422.6796709571, 22309.625...
#
#                                                 Transport
# 0       [635.261039442742, 587.88351950614, 398.080163...
# 1       [721.195093066016, 196.239079252915, 203.93087...
# 2       [520.265689581308, 437.32159204288, 959.443184...
# 3       [668.923563658238, 657.668594681302, 183.46490...
# 4       [517.525240373194, 727.236630893907, 1499.8140...
# ...                                                   ...
# 246332  [852.474399859055, 918.329988534318, 626.37911...
# 246333  [828.634638979598, 894.684643959268, 603.76960...
# 246334  [821.922386442375, 888.402754588013, 599.58242...
# 246335  [817.706789476209, 883.966012643017, 594.11169...
# 246336  [867.740534966257, 934.035116432711, 643.88741...
#
# [246337 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Building', 'name_en', 'building', 'building_l', 'building_m',
#        'addr_full', 'addr_house', 'addr_stree', 'addr_city', 'office',
#        'source', 'name_tr', 'osm_id', 'osm_type', 'adm1_tr', 'adm1_en', 'adm1',
#        'Shape_Leng', 'Shape_Area', 'adm0_en', 'adm0_tr', 'adm0', 'lon', 'lat',
#        'Civic', 'Fire', 'Government', 'Hospital', 'Public', 'School', 'Sports',
#        'Supermarket', 'Toilet', 'Transport'],
#       dtype='object')

# %%
df[['Civic', 'Fire', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Supermarket', 'Toilet', 'Transport']] = df[['Civic', 'Fire', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Supermarket', 'Toilet', 'Transport']].applymap(lambda x: np.divide(x, 10000) if isinstance(x, list) else x)

# %%
#df[['Civic', 'Government']] = df[['Civic', 'Government']].applymap(lambda x: np.divide(x, 10000) if isinstance(x, list) else x)

# %%
distance_map = {
    'Civic': 1.5,
    'Fire': 1.0,
    'Government': 10.0,
    'Hospital': 10.0,
    'Public': 2.0,
    'School': 1.0,
    'Sports': 1.5,
    'Supermarket': 1.0,
    'Toilet': 0.1,
    'Transport': 2.0,
}
for facility, max_dist in distance_map.items():
    try:
        df[f'{facility}_nearby'] = df[facility].apply(lambda lst: [d for d in lst if d <= max_dist])
    except:
        pass


for facility, max_dist in distance_map.items():
    try:
        df[f'{facility}_nearby'] = df[f'{facility}_nearby'].apply(lambda lst: [round(max_dist - d, 2) for d in lst])
    except:
        pass


for facility in distance_map:
    try:
        df[f'{facility}_Score'] = df[f'{facility}_nearby'].apply(sum)
    except:
        pass

from sklearn.preprocessing import MinMaxScaler

# Select score columns
score_cols = [col for col in df.columns if col.endswith('_Score')]

# Initialize scaler with feature range 0-10
scaler = MinMaxScaler(feature_range=(0, 10))

# Fit and transform, then round to 2 decimals
df[score_cols] = pd.DataFrame(
    scaler.fit_transform(df[score_cols]),
    columns=score_cols,
    index=df.index
).round(2)

# %%
df
# Out:
#                       Building name_en building building_l  building_m  \
# 0            IstanbulBuilding0     NaN      yes        NaN         NaN
# 1            IstanbulBuilding1     NaN      yes        NaN         NaN
# 2            IstanbulBuilding2     NaN      yes        NaN         NaN
# 3            IstanbulBuilding3     NaN      yes        NaN         NaN
# 4            IstanbulBuilding4     NaN      yes        NaN         NaN
# ...                        ...     ...      ...        ...         ...
# 246332  IstanbulBuilding259781     NaN      yes        NaN         NaN
# 246333  IstanbulBuilding259782     NaN      yes        NaN         NaN
# 246334  IstanbulBuilding259783     NaN      yes        NaN         NaN
# 246335  IstanbulBuilding259784     NaN      yes        NaN         NaN
# 246336  IstanbulBuilding259785     NaN      yes        NaN         NaN
#
#        addr_full addr_house addr_stree addr_city office  ... Civic_Score  \
# 0            NaN        NaN        NaN       NaN    NaN  ...        8.20
# 1            NaN        NaN        NaN       NaN    NaN  ...        8.12
# 2            NaN        NaN        NaN       NaN    NaN  ...        8.35
# 3            NaN        NaN        NaN       NaN    NaN  ...        8.13
# 4            NaN        NaN        NaN       NaN    NaN  ...        6.59
# ...          ...        ...        ...       ...    ...  ...         ...
# 246332       NaN        NaN        NaN       NaN    NaN  ...        8.16
# 246333       NaN        NaN        NaN       NaN    NaN  ...        8.16
# 246334       NaN        NaN        NaN       NaN    NaN  ...        8.16
# 246335       NaN        NaN        NaN       NaN    NaN  ...        8.16
# 246336       NaN        NaN        NaN       NaN    NaN  ...        8.16
#
#        Fire_Score  Government_Score Hospital_Score Public_Score School_Score  \
# 0            0.00              9.97           9.72         9.66         8.36
# 1            0.00              9.94           9.68         9.71         8.12
# 2            0.00              9.99           9.78         9.66         8.38
# 3            0.00              9.95           9.68         9.72         8.21
# 4            4.34              9.49           9.71         8.81         8.19
# ...           ...               ...            ...          ...          ...
# 246332       0.00              9.85           9.84         9.33         8.21
# 246333       0.00              9.85           9.85         9.33         8.21
# 246334       0.00              9.85           9.85         9.35         8.21
# 246335       0.00              9.85           9.85         9.35         8.21
# 246336       0.00              9.85           9.84         9.32         3.41
#
#        Sports_Score  Supermarket_Score  Toilet_Score Transport_Score
# 0              9.45               0.89          0.00            9.74
# 1              9.30               0.83          0.00            9.78
# 2              9.86               1.11          0.00            9.65
# 3              9.35               0.85          0.00            9.79
# 4              7.54               0.02          0.00            9.62
# ...             ...                ...           ...             ...
# 246332         9.23               1.45          4.44            9.62
# 246333         9.23               1.45          4.44            9.63
# 246334         9.23               1.45          4.44            9.63
# 246335         9.23               1.45          4.44            9.63
# 246336         9.22               1.45          3.33            9.62
#
# [246337 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['Building', 'name_en', 'building', 'building_l', 'building_m',
#        'addr_full', 'addr_house', 'addr_stree', 'addr_city', 'office',
#        'source', 'name_tr', 'osm_id', 'osm_type', 'adm1_tr', 'adm1_en', 'adm1',
#        'Shape_Leng', 'Shape_Area', 'adm0_en', 'adm0_tr', 'adm0', 'lon', 'lat',
#        'Civic', 'Fire', 'Government', 'Hospital', 'Public', 'School', 'Sports',
#        'Supermarket', 'Toilet', 'Transport', 'Civic_nearby', 'Fire_nearby',
#        'Government_nearby', 'Hospital_nearby', 'Public_nearby',
#        'School_nearby', 'Sports_nearby', 'Supermarket_nearby', 'Toilet_nearby',
#        'Transport_nearby', 'Civic_Score', 'Fire_Score', 'Government_Score',
#        'Hospital_Score', 'Public_Score', 'School_Score', 'Sports_Score',
#        'Supermarket_Score', 'Toilet_Score', 'Transport_Score'],
#       dtype='object')

# %%
df = df[['Building', 'lon', 'lat',
       'Civic_Score', 'Fire_Score', 'Government_Score',
       'Hospital_Score', 'Public_Score', 'School_Score', 'Sports_Score',
       'Supermarket_Score', 'Toilet_Score', 'Transport_Score']]

# %%
df.to_csv('IstanbulScoreRAW1.csv', index = False)

# %%
# %%time
columns = ['Civic', 'Fire', 'Government', 'Hospital', 'Public', 
           'School', 'Sports', 'Supermarket', 'Toilet', 'Transport']

for col in columns:
    df[f'{col}_1km'] = None
    df[f'{col}_5km'] = None
    df[f'{col}_10km'] = None
# Out:
# CPU times: total: 125 ms
# Wall time: 137 ms

# %%
# %%time
# Define columns
columns = ['Civic', 'Fire', 'Government', 'Hospital', 'Public', 
           'School', 'Sports', 'Supermarket', 'Toilet', 'Transport']

# Define a function to filter numbers based on distance
def filter_distances(row, columns):
    for col in columns:
        row[f'{col}_1km'] = [number for number in row[col] if number <= 1]
        row[f'{col}_5km'] = [number for number in row[col] if number <= 5]
        row[f'{col}_10km'] = [number for number in row[col] if number <= 10]
    return row

# Apply the function across the dataframe
df = df.apply(lambda row: filter_distances(row, columns), axis=1)
# Out:
# CPU times: total: 4min 35s
# Wall time: 4min 41s

# %%
df
# Out:
#                       Building name_en building building_l  building_m  \
# 0            IstanbulBuilding0     NaN      yes        NaN         NaN
# 1            IstanbulBuilding1     NaN      yes        NaN         NaN
# 2            IstanbulBuilding2     NaN      yes        NaN         NaN
# 3            IstanbulBuilding3     NaN      yes        NaN         NaN
# 4            IstanbulBuilding4     NaN      yes        NaN         NaN
# ...                        ...     ...      ...        ...         ...
# 246332  IstanbulBuilding259781     NaN      yes        NaN         NaN
# 246333  IstanbulBuilding259782     NaN      yes        NaN         NaN
# 246334  IstanbulBuilding259783     NaN      yes        NaN         NaN
# 246335  IstanbulBuilding259784     NaN      yes        NaN         NaN
# 246336  IstanbulBuilding259785     NaN      yes        NaN         NaN
#
#         addr_full addr_house addr_stree addr_city office  ...  \
# 0             NaN        NaN        NaN       NaN    NaN  ...
# 1             NaN        NaN        NaN       NaN    NaN  ...
# 2             NaN        NaN        NaN       NaN    NaN  ...
# 3             NaN        NaN        NaN       NaN    NaN  ...
# 4             NaN        NaN        NaN       NaN    NaN  ...
# ...           ...        ...        ...       ...    ...  ...
# 246332        NaN        NaN        NaN       NaN    NaN  ...
# 246333        NaN        NaN        NaN       NaN    NaN  ...
# 246334        NaN        NaN        NaN       NaN    NaN  ...
# 246335        NaN        NaN        NaN       NaN    NaN  ...
# 246336        NaN        NaN        NaN       NaN    NaN  ...
#
#                                               Sports_10km  \
# 0       [0.100213684865337, 0.107001990063315, 0.10361...
# 1       [0.120120550208683, 0.12425258061066599, 0.120...
# 2       [0.0316010482586767, 0.0434649834970953, 0.041...
# 3       [0.113385169483486, 0.11775854090678799, 0.114...
# 4       [0.362452322243564, 0.243326425391115, 0.34359...
# ...                                                   ...
# 246332  [0.170427267597839, 0.177609615058402, 0.16936...
# 246333  [0.168190572841109, 0.17544181196178, 0.171442...
# 246334  [0.166614936179323, 0.173824288334567, 0.17544...
# 246335  [0.16687330916048, 0.174137626213664, 0.175747...
# 246336  [0.170459500200062, 0.177503738864002, 0.16966...
#
#                                  Supermarket_1km  \
# 0       [0.8390171250425121, 0.7225305862121799]
# 1        [0.8704664894254039, 0.724800610883859]
# 2        [0.7761802292238109, 0.668120973192039]
# 3         [0.863784674971357, 0.720872074276735]
# 4                            [0.986393277449103]
# ...                                          ...
# 246332    [0.607033174819925, 0.673177853455259]
# 246333   [0.6094388017070209, 0.673431330075868]
# 246334    [0.610835017203818, 0.672212766931551]
# 246335     [0.610763833922659, 0.67315028453646]
# 246336   [0.6065722681117319, 0.671037982433598]
#
#                                           Supermarket_5km  \
# 0       [1.9966486235923102, 1.9989196050953801, 1.650...
# 1       [2.01323056237067, 2.0156892118699403, 1.64533...
# 2       [2.01617907569297, 2.01793735793746, 1.7130430...
# 3       [2.01290070680966, 2.01531127827301, 1.6496067...
# 4       [1.2974955929026901, 1.30445270183349, 1.30230...
# ...                                                   ...
# 246332  [1.96057447435161, 1.96121498185429, 1.7732195...
# 246333  [1.96066981901334, 1.96132797155538, 1.7716901...
# 246334  [1.9620541084601397, 1.96271970508366, 1.77206...
# 246335  [1.9611350997164, 1.96180210438654, 1.77124007...
# 246336  [1.96258689855581, 1.96321975070308, 1.7754454...
#
#                                          Supermarket_10km  \
# 0       [1.9966486235923102, 1.9989196050953801, 1.650...
# 1       [2.01323056237067, 2.0156892118699403, 1.64533...
# 2       [2.01617907569297, 2.01793735793746, 1.7130430...
# 3       [2.01290070680966, 2.01531127827301, 1.6496067...
# 4       [1.2974955929026901, 1.30445270183349, 1.30230...
# ...                                                   ...
# 246332  [1.96057447435161, 1.96121498185429, 1.7732195...
# 246333  [1.96066981901334, 1.96132797155538, 1.7716901...
# 246334  [1.9620541084601397, 1.96271970508366, 1.77206...
# 246335  [1.9611350997164, 1.96180210438654, 1.77124007...
# 246336  [1.96258689855581, 1.96321975070308, 1.7754454...
#
#                    Toilet_1km  \
# 0       [0.22965873683465302]
# 1         [0.261629746801393]
# 2         [0.179703667081676]
# 3         [0.255339722102633]
# 4         [0.756734770162942]
# ...                       ...
# 246332   [0.0642682314170713]
# 246333   [0.0636340148572854]
# 246334   [0.0646900959642187]
# 246335   [0.0637518973587302]
# 246336  [0.06651365314978851]
#
#                                                Toilet_5km  \
# 0       [0.22965873683465302, 2.4263820923906003, 2.10...
# 1       [0.261629746801393, 2.42219719411727, 2.082773...
# 2       [0.179703667081676, 2.48766924256517, 2.113066...
# 3       [0.255339722102633, 2.4263379207507003, 2.0850...
# 4       [0.756734770162942, 1.73333654070128, 2.758919...
# ...                                                   ...
# 246332  [0.0642682314170713, 2.5400162130037502, 2.232...
# 246333  [0.0636340148572854, 2.53861081160745, 2.23088...
# 246334  [0.0646900959642187, 2.53909162755521, 2.22916...
# 246335  [0.0637518973587302, 2.5382388874673403, 2.229...
# 246336  [0.06651365314978851, 2.54226796709571, 2.2309...
#
#                                               Toilet_10km  \
# 0       [0.22965873683465302, 2.4263820923906003, 2.10...
# 1       [0.261629746801393, 2.42219719411727, 2.082773...
# 2       [0.179703667081676, 2.48766924256517, 2.113066...
# 3       [0.255339722102633, 2.4263379207507003, 2.0850...
# 4       [0.756734770162942, 1.73333654070128, 2.758919...
# ...                                                   ...
# 246332  [0.0642682314170713, 2.5400162130037502, 2.232...
# 246333  [0.0636340148572854, 2.53861081160745, 2.23088...
# 246334  [0.0646900959642187, 2.53909162755521, 2.22916...
# 246335  [0.0637518973587302, 2.5382388874673403, 2.229...
# 246336  [0.06651365314978851, 2.54226796709571, 2.2309...
#
#                                             Transport_1km  \
# 0       [0.0635261039442742, 0.058788351950614, 0.0398...
# 1       [0.0721195093066016, 0.0196239079252915, 0.020...
# 2       [0.052026568958130806, 0.043732159204288, 0.09...
# 3       [0.0668923563658238, 0.0657668594681302, 0.018...
# 4       [0.051752524037319406, 0.0727236630893907, 0.1...
# ...                                                   ...
# 246332  [0.0852474399859055, 0.0918329988534318, 0.062...
# 246333  [0.0828634638979598, 0.0894684643959268, 0.060...
# 246334  [0.0821922386442375, 0.0888402754588013, 0.059...
# 246335  [0.0817706789476209, 0.08839660126430171, 0.05...
# 246336  [0.0867740534966257, 0.0934035116432711, 0.064...
#
#                                             Transport_5km  \
# 0       [0.0635261039442742, 0.058788351950614, 0.0398...
# 1       [0.0721195093066016, 0.0196239079252915, 0.020...
# 2       [0.052026568958130806, 0.043732159204288, 0.09...
# 3       [0.0668923563658238, 0.0657668594681302, 0.018...
# 4       [0.051752524037319406, 0.0727236630893907, 0.1...
# ...                                                   ...
# 246332  [0.0852474399859055, 0.0918329988534318, 0.062...
# 246333  [0.0828634638979598, 0.0894684643959268, 0.060...
# 246334  [0.0821922386442375, 0.0888402754588013, 0.059...
# 246335  [0.0817706789476209, 0.08839660126430171, 0.05...
# 246336  [0.0867740534966257, 0.0934035116432711, 0.064...
#
#                                            Transport_10km
# 0       [0.0635261039442742, 0.058788351950614, 0.0398...
# 1       [0.0721195093066016, 0.0196239079252915, 0.020...
# 2       [0.052026568958130806, 0.043732159204288, 0.09...
# 3       [0.0668923563658238, 0.0657668594681302, 0.018...
# 4       [0.051752524037319406, 0.0727236630893907, 0.1...
# ...                                                   ...
# 246332  [0.0852474399859055, 0.0918329988534318, 0.062...
# 246333  [0.0828634638979598, 0.0894684643959268, 0.060...
# 246334  [0.0821922386442375, 0.0888402754588013, 0.059...
# 246335  [0.0817706789476209, 0.08839660126430171, 0.05...
# 246336  [0.0867740534966257, 0.0934035116432711, 0.064...
#
# [246337 rows x 64 columns]

# %%
# %%time
# Define columns
columns = ['Civic', 'Fire', 'Government', 'Hospital', 'Public', 
           'School', 'Sports', 'Supermarket', 'Toilet', 'Transport']

# Define a function to apply element-wise
def transform_list(lst, val):
    return [round(val - x, 2) for x in lst]

# Use applymap to vectorize calculations
for col in columns:
    df[f'{col}_1km'] = df[f'{col}_1km'].map(lambda x: transform_list(x, 1))
    df[f'{col}_5km'] = df[f'{col}_5km'].map(lambda x: transform_list(x, 5))
    df[f'{col}_10km'] = df[f'{col}_10km'].map(lambda x: transform_list(x, 10))
# Out:
# CPU times: total: 5min 34s
# Wall time: 5min 54s

# %%
# %%time
# Define columns
columns = ['Civic', 'Fire', 'Government', 'Hospital', 'Public', 
           'School', 'Sports', 'Supermarket', 'Toilet', 'Transport']

# Initialize score columns
for col in columns:
    df[f'{col}_1km_Score'] = None
    df[f'{col}_5km_Score'] = None
    df[f'{col}_10km_Score'] = None

# Define a function to calculate scores
def calculate_scores(row, columns):
    for col in columns:
        row[f'{col}_1km_Score'] = sum(row[f'{col}_1km'])
        row[f'{col}_5km_Score'] = sum(row[f'{col}_5km'])
        row[f'{col}_10km_Score'] = sum(row[f'{col}_10km'])
    return row

# Apply the function across the dataframe
df = df.apply(lambda row: calculate_scores(row, columns), axis=1)
# Out:
# CPU times: total: 6min 25s
# Wall time: 7min 51s

# %%
df
# Out:
#                       Building name_en building building_l  building_m  \
# 0            IstanbulBuilding0     NaN      yes        NaN         NaN
# 1            IstanbulBuilding1     NaN      yes        NaN         NaN
# 2            IstanbulBuilding2     NaN      yes        NaN         NaN
# 3            IstanbulBuilding3     NaN      yes        NaN         NaN
# 4            IstanbulBuilding4     NaN      yes        NaN         NaN
# ...                        ...     ...      ...        ...         ...
# 246332  IstanbulBuilding259781     NaN      yes        NaN         NaN
# 246333  IstanbulBuilding259782     NaN      yes        NaN         NaN
# 246334  IstanbulBuilding259783     NaN      yes        NaN         NaN
# 246335  IstanbulBuilding259784     NaN      yes        NaN         NaN
# 246336  IstanbulBuilding259785     NaN      yes        NaN         NaN
#
#         addr_full addr_house addr_stree addr_city office  ...  \
# 0             NaN        NaN        NaN       NaN    NaN  ...
# 1             NaN        NaN        NaN       NaN    NaN  ...
# 2             NaN        NaN        NaN       NaN    NaN  ...
# 3             NaN        NaN        NaN       NaN    NaN  ...
# 4             NaN        NaN        NaN       NaN    NaN  ...
# ...           ...        ...        ...       ...    ...  ...
# 246332        NaN        NaN        NaN       NaN    NaN  ...
# 246333        NaN        NaN        NaN       NaN    NaN  ...
# 246334        NaN        NaN        NaN       NaN    NaN  ...
# 246335        NaN        NaN        NaN       NaN    NaN  ...
# 246336        NaN        NaN        NaN       NaN    NaN  ...
#
#        Sports_10km_Score Supermarket_1km_Score  Supermarket_5km_Score  \
# 0                  49.37                  0.44                  17.79
# 1                  49.26                  0.41                  17.73
# 2                  49.67                  0.55                  17.80
# 3                  49.30                  0.42                  17.74
# 4                  47.98                  0.01                  18.99
# ...                  ...                   ...                    ...
# 246332             49.21                  0.72                  18.03
# 246333             49.21                  0.72                  18.03
# 246334             49.21                  0.72                  18.03
# 246335             49.21                  0.72                  18.03
# 246336             49.20                  0.72                  18.02
#
#        Supermarket_10km_Score Toilet_1km_Score Toilet_5km_Score  \
# 0                       42.79             0.77            10.23
# 1                       42.73             0.74            10.24
# 2                       42.80             0.82            10.22
# 3                       42.74             0.74            10.22
# 4                       43.99             0.24             9.75
# ...                       ...              ...              ...
# 246332                  43.03             0.94            10.17
# 246333                  43.03             0.94            10.17
# 246334                  43.03             0.94            10.17
# 246335                  43.03             0.94            10.17
# 246336                  43.02             0.93            10.16
#
#        Toilet_10km_Score  Transport_1km_Score  Transport_5km_Score  \
# 0                  25.23                 4.71                24.71
# 1                  25.24                 4.75                24.75
# 2                  25.22                 4.62                24.62
# 3                  25.22                 4.76                24.76
# 4                  24.75                 4.59                24.59
# ...                  ...                  ...                  ...
# 246332             25.17                 4.59                24.59
# 246333             25.17                 4.60                24.60
# 246334             25.17                 4.60                24.60
# 246335             25.17                 4.60                24.60
# 246336             25.16                 4.59                24.59
#
#        Transport_10km_Score
# 0                     49.71
# 1                     49.75
# 2                     49.62
# 3                     49.76
# 4                     49.59
# ...                     ...
# 246332                49.59
# 246333                49.60
# 246334                49.60
# 246335                49.60
# 246336                49.59
#
# [246337 rows x 94 columns]

# %%
df.columns[94]

# %%
# Vectorized scaling operation
df.iloc[:, 64:94] = df.iloc[:, 64:94].apply(lambda col: (col - col.min()) / (col.max() - col.min()) * 10, axis=0)

# %%
# Optimized approach
try:
    df.iloc[:, 64:94] = df.iloc[:, 64:94].astype(float).round(2)
except Exception as e:
    print('Error:', e)

# %%
df
# Out:
#                       Building name_en building building_l  building_m  \
# 0            IstanbulBuilding0     NaN      yes        NaN         NaN
# 1            IstanbulBuilding1     NaN      yes        NaN         NaN
# 2            IstanbulBuilding2     NaN      yes        NaN         NaN
# 3            IstanbulBuilding3     NaN      yes        NaN         NaN
# 4            IstanbulBuilding4     NaN      yes        NaN         NaN
# ...                        ...     ...      ...        ...         ...
# 246332  IstanbulBuilding259781     NaN      yes        NaN         NaN
# 246333  IstanbulBuilding259782     NaN      yes        NaN         NaN
# 246334  IstanbulBuilding259783     NaN      yes        NaN         NaN
# 246335  IstanbulBuilding259784     NaN      yes        NaN         NaN
# 246336  IstanbulBuilding259785     NaN      yes        NaN         NaN
#
#         addr_full addr_house addr_stree addr_city office  ...  \
# 0             NaN        NaN        NaN       NaN    NaN  ...
# 1             NaN        NaN        NaN       NaN    NaN  ...
# 2             NaN        NaN        NaN       NaN    NaN  ...
# 3             NaN        NaN        NaN       NaN    NaN  ...
# 4             NaN        NaN        NaN       NaN    NaN  ...
# ...           ...        ...        ...       ...    ...  ...
# 246332        NaN        NaN        NaN       NaN    NaN  ...
# 246333        NaN        NaN        NaN       NaN    NaN  ...
# 246334        NaN        NaN        NaN       NaN    NaN  ...
# 246335        NaN        NaN        NaN       NaN    NaN  ...
# 246336        NaN        NaN        NaN       NaN    NaN  ...
#
#        Sports_10km_Score Supermarket_1km_Score  Supermarket_5km_Score  \
# 0                   9.89                  0.89                   7.13
# 1                   9.86                  0.83                   7.10
# 2                   9.97                  1.11                   7.13
# 3                   9.87                  0.85                   7.11
# 4                   9.50                  0.02                   7.61
# ...                  ...                   ...                    ...
# 246332              9.84                  1.45                   7.22
# 246333              9.84                  1.45                   7.22
# 246334              9.84                  1.45                   7.22
# 246335              9.84                  1.45                   7.22
# 246336              9.84                  1.45                   7.22
#
#        Supermarket_10km_Score Toilet_1km_Score Toilet_5km_Score  \
# 0                        8.17             7.78             9.97
# 1                        8.15             7.47             9.98
# 2                        8.17             8.28             9.96
# 3                        8.15             7.47             9.96
# 4                        8.47             2.42             9.50
# ...                       ...              ...              ...
# 246332                   8.23             9.49             9.91
# 246333                   8.23             9.49             9.91
# 246334                   8.23             9.49             9.91
# 246335                   8.23             9.49             9.91
# 246336                   8.23             9.39             9.90
#
#        Toilet_10km_Score  Transport_1km_Score  Transport_5km_Score  \
# 0                   9.99                 9.48                 9.90
# 1                   9.99                 9.56                 9.91
# 2                   9.98                 9.30                 9.86
# 3                   9.98                 9.58                 9.92
# 4                   9.78                 9.24                 9.85
# ...                  ...                  ...                  ...
# 246332              9.96                 9.24                 9.85
# 246333              9.96                 9.26                 9.85
# 246334              9.96                 9.26                 9.85
# 246335              9.96                 9.26                 9.85
# 246336              9.96                 9.24                 9.85
#
#        Transport_10km_Score
# 0                      9.91
# 1                      9.92
# 2                      9.87
# 3                      9.92
# 4                      9.86
# ...                     ...
# 246332                 9.86
# 246333                 9.87
# 246334                 9.87
# 246335                 9.87
# 246336                 9.86
#
# [246337 rows x 94 columns]

# %%
df.to_csv('IstanbulScoreRAW.csv', index = False)
