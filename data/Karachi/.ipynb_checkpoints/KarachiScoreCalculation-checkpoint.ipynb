# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from geopy.geocoders import Nominatim
from math import radians, cos, sin, asin, sqrt
from numpy import cos, sin, arcsin, sqrt
from ast import literal_eval
from tqdm import tqdm
import requests
import json
import networkx as nx
import osmnx as ox
import requests
from geopy import Point
from geopy.distance import geodesic
import numpy as np

# %%
df_building = pd.read_csv('KarachiBuildingsFinal.csv')

# %%
df_building.rename(columns={'name' : 'Building'}, inplace = True)

# %%
df_civic = pd.read_csv('CivicDistance.csv')
df_government = pd.read_csv('GovernmentDistance.csv')
df_hospital = pd.read_csv('HospitalDistance.csv')
df_public = pd.read_csv('PublicDistance.csv')
df_school = pd.read_csv('SchoolDistance.csv')
df_sports = pd.read_csv('SportsDistance.csv')
df_transport = pd.read_csv('TransportDistance.csv')

# %%
df_civic = df_civic.groupby('InputID').agg(lambda x: list(x))
df_government = df_government.groupby('InputID').agg(lambda x: list(x))
df_hospital = df_hospital.groupby('InputID').agg(lambda x: list(x))
df_public = df_public.groupby('InputID').agg(lambda x: list(x))
df_school = df_school.groupby('InputID').agg(lambda x: list(x))
df_sports = df_sports.groupby('InputID').agg(lambda x: list(x))
df_transport = df_transport.groupby('InputID').agg(lambda x: list(x))

# %%
df_civic = df_civic.reset_index()
df_government = df_government.reset_index()
df_hospital = df_hospital.reset_index()
df_public = df_public.reset_index()
df_school = df_school.reset_index()
df_sports = df_sports.reset_index()
df_transport = df_transport.reset_index()

# %%
df_civic.drop(columns=['TargetID'], inplace = True)
df_government.drop(columns=['TargetID'], inplace = True)
df_hospital.drop(columns=['TargetID'], inplace = True)
df_public.drop(columns=['TargetID'], inplace = True)
df_school.drop(columns=['TargetID'], inplace = True)
df_sports.drop(columns=['TargetID'], inplace = True)
df_transport.drop(columns=['TargetID'], inplace = True)

# %%
df_civic
df_fire
df_government
df_hospital
df_public
df_school
df_sports
df_supermarket
df_toilet
df_transport

# %%
df_civic.rename(columns={'InputID':'Building', 'Distance':'Civic'}, inplace = True)
df_government.rename(columns={'InputID':'Building', 'Distance':'Government'}, inplace = True)
df_hospital.rename(columns={'InputID':'Building', 'Distance':'Hospital'}, inplace = True)
df_public.rename(columns={'InputID':'Building', 'Distance':'Public'}, inplace = True)
df_school.rename(columns={'InputID':'Building', 'Distance':'School'}, inplace = True)
df_sports.rename(columns={'InputID':'Building', 'Distance':'Sports'}, inplace = True)
df_transport.rename(columns={'InputID':'Building', 'Distance':'Transport'}, inplace = True)

# %%
df = df_building.merge(df_civic, on='Building', how = 'inner')
df = df.merge(df_government, on='Building', how = 'inner')
df = df.merge(df_hospital, on='Building', how = 'inner')
df = df.merge(df_public, on='Building', how = 'inner')
df = df.merge(df_school, on='Building', how = 'inner')
df = df.merge(df_sports, on='Building', how = 'inner')
df = df.merge(df_transport, on='Building', how = 'inner')

# %%
df
# Out:
#                    Building name_en building  building_l  building_m  \
# 0          KarachiBuilding0     NaN      yes         NaN         NaN
# 1          KarachiBuilding1     NaN      yes         NaN         NaN
df[['Civic', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Transport']] = df[['Civic', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Transport']].applymap(lambda x: np.divide(x, 10000) if isinstance(x, list) else x)

# %%
#df[['Civic', 'Government']] = df[['Civic', 'Government']].applymap(lambda x: np.divide(x, 10000) if isinstance(x, list) else x)

# %%
distance_map = {
    'Civic': 1.5,
    'Fire': 1.0,
    'Government': 10.0,
    'Hospital': 10.0,
    'Public': 2.0,
    'School': 1.0,
    'Sports': 1.5,
    'Supermarket': 1.0,
    'Toilet': 0.1,
    'Transport': 2.0,
}
for facility, max_dist in distance_map.items():
    try:
        df[f'{facility}_nearby'] = df[facility].apply(lambda lst: [d for d in lst if d <= max_dist])
    except:
        pass


for facility, max_dist in distance_map.items():
    try:
        df[f'{facility}_nearby'] = df[f'{facility}_nearby'].apply(lambda lst: [round(max_dist - d, 2) for d in lst])
    except:
        pass


for facility in distance_map:
    try:
        df[f'{facility}_Score'] = df[f'{facility}_nearby'].apply(sum)
    except:
        pass

from sklearn.preprocessing import MinMaxScaler

# Select score columns
score_cols = [col for col in df.columns if col.endswith('_Score')]

# Initialize scaler with feature range 0-10
scaler = MinMaxScaler(feature_range=(0, 10))

# Fit and transform, then round to 2 decimals
df[score_cols] = pd.DataFrame(
    scaler.fit_transform(df[score_cols]),
    columns=score_cols,
    index=df.index
).round(2)

# %%
df
# Out:
#                    Building name_en building  building_l  building_m  \
# 0          KarachiBuilding0     NaN      yes         NaN         NaN
# 1          KarachiBuilding1     NaN      yes         NaN         NaN
# 2          KarachiBuilding2     NaN      yes         NaN         NaN
# 3          KarachiBuilding3     NaN      yes         NaN         NaN
# 4          KarachiBuilding4     NaN      yes         NaN         NaN
# ...                     ...     ...      ...         ...         ...
# 74097  KarachiBuilding76227     NaN    house         NaN         NaN
# 74098  KarachiBuilding76228     NaN    house         NaN         NaN
# 74099  KarachiBuilding76229     NaN    house         NaN         NaN
# 74100  KarachiBuilding76230     NaN    house         NaN         NaN
# 74101  KarachiBuilding76231     NaN    house         NaN         NaN
#
#       addr_full addr_house addr_stree addr_city office  ...  \
# 0           NaN        NaN        NaN       NaN    NaN  ...
# 1           NaN        NaN        NaN       NaN    NaN  ...
# 2           NaN        NaN        NaN       NaN    NaN  ...
# 3           NaN        NaN        NaN       NaN    NaN  ...
# 4           NaN        NaN        NaN       NaN    NaN  ...
# ...         ...        ...        ...       ...    ...  ...
# 74097       NaN        NaN        NaN       NaN    NaN  ...
# 74098       NaN        NaN        NaN       NaN    NaN  ...
# 74099       NaN        NaN        NaN       NaN    NaN  ...
# 74100       NaN        NaN        NaN       NaN    NaN  ...
# 74101       NaN        NaN        NaN       NaN    NaN  ...
#
#                         School_nearby                   Sports_nearby  \
# 0      [0.66, 0.71, 0.64, 0.84, 0.84]  [1.16, 1.16, 1.16, 1.24, 1.23]
# 1      [0.88, 0.91, 0.86, 0.94, 0.94]  [1.36, 1.36, 1.35, 1.39, 1.39]
# 2      [0.83, 0.85, 0.79, 0.95, 0.95]  [1.33, 1.33, 1.32, 1.34, 1.33]
# 3      [0.85, 0.88, 0.88, 0.82, 0.82]  [1.36, 1.37, 1.36, 1.36, 1.28]
# 4      [0.85, 0.81, 0.88, 0.88, 0.82]  [1.36, 1.37, 1.36, 1.36, 1.29]
# ...                               ...                             ...
# 74097  [0.97, 0.96, 0.93, 0.93, 0.92]  [0.69, 0.68, 0.96, 0.68, 0.69]
# 74098  [0.97, 0.96, 0.93, 0.93, 0.93]  [0.69, 0.68, 0.96, 0.68, 0.69]
# 74099  [0.97, 0.96, 0.93, 0.93, 0.92]  [0.69, 0.68, 0.96, 0.68, 0.69]
# 74100  [0.97, 0.96, 0.93, 0.93, 0.92]  [0.69, 0.68, 0.96, 0.68, 0.69]
# 74101  [0.97, 0.96, 0.93, 0.93, 0.92]  [0.69, 0.68, 0.96, 0.68, 0.69]
#
#        Transport_nearby Civic_Score  Government_Score  Hospital_Score  \
# 0          [1.47, 0.13]        4.67              8.22            9.34
# 1          [1.69, 0.28]        6.07              8.46            9.73
# 2          [1.63, 0.27]        5.60              8.44            9.65
# 3          [1.63, 0.34]        5.60              8.56            9.71
# 4          [1.63, 0.34]        5.60              8.56            9.72
# ...                 ...         ...               ...             ...
# 74097      [1.07, 1.04]        8.40              8.83            9.84
# 74098      [1.07, 1.04]        8.47              8.83            9.84
# 74099      [1.07, 1.04]        8.47              8.83            9.84
# 74100      [1.07, 1.04]        8.47              8.83            9.84
# 74101      [1.07, 1.05]        8.47              8.83            9.84
#
#       Public_Score School_Score  Sports_Score  Transport_Score
# 0             4.99         7.39          7.99             6.56
# 1             5.70         9.08          9.19             8.07
# 2             5.63         8.76          8.93             7.79
# 3             5.95         8.52          9.03             8.07
# 4             5.93         8.50          9.05             8.07
# ...            ...          ...           ...              ...
# 74097         5.73         9.44          4.97             8.65
# 74098         5.73         9.46          4.97             8.65
# 74099         5.73         9.44          4.97             8.65
# 74100         5.73         9.44          4.97             8.65
# 74101         5.73         9.44          4.97             8.69
#
# [74102 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['Building', 'name_en', 'building', 'building_l', 'building_m',
#        'addr_full', 'addr_house', 'addr_stree', 'addr_city', 'office',
#        'source', 'name_ur', 'osm_id', 'osm_type', 'Shape_Leng', 'Shape_Area',
#        'ADM2_EN', 'ADM2_PCODE', 'ADM2_REF', 'ADM2ALT1EN', 'ADM2ALT2EN',
#        'ADM1_EN', 'ADM1_PCODE', 'ADM0_EN', 'ADM0_PCODE', 'date', 'validOn',
#        'validTo', 'lon', 'lat', 'Civic', 'Government', 'Hospital', 'Public',
#        'School', 'Sports', 'Transport', 'Civic_nearby', 'Government_nearby',
#        'Hospital_nearby', 'Public_nearby', 'School_nearby', 'Sports_nearby',
#        'Transport_nearby', 'Civic_Score', 'Government_Score', 'Hospital_Score',
#        'Public_Score', 'School_Score', 'Sports_Score', 'Transport_Score'],
#       dtype='object')

# %%
df = df[['Building', 'lon', 'lat', 'Civic', 'Civic_Score', 'Government_Score', 'Hospital_Score',
       'Public_Score', 'School_Score', 'Sports_Score', 'Transport_Score']]

# %%
df.to_csv('KarachiScoreRAW1.csv', index = False)

# %%
# %%time
columns = ['Civic', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Transport']

for col in columns:
    df[f'{col}_1km'] = None
    df[f'{col}_5km'] = None
    df[f'{col}_10km'] = None
# Out:
# CPU times: total: 46.9 ms
# Wall time: 50.9 ms

# %%
# %%time
# Define columns
columns = ['Civic', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Transport']

# Define a function to filter numbers based on distance
def filter_distances(row, columns):
    for col in columns:
        row[f'{col}_1km'] = [number for number in row[col] if number <= 1]
        row[f'{col}_5km'] = [number for number in row[col] if number <= 5]
        row[f'{col}_10km'] = [number for number in row[col] if number <= 10]
    return row

# Apply the function across the dataframe
df = df.apply(lambda row: filter_distances(row, columns), axis=1)
# Out:
# CPU times: total: 1min 12s
# Wall time: 1min 14s

# %%
df
# Out:
#                    Building name_en building  building_l  building_m  \
# 0          KarachiBuilding0     NaN      yes         NaN         NaN
# 1          KarachiBuilding1     NaN      yes         NaN         NaN
# 2          KarachiBuilding2     NaN      yes         NaN         NaN
# 3          KarachiBuilding3     NaN      yes         NaN         NaN
# 4          KarachiBuilding4     NaN      yes         NaN         NaN
# ...                     ...     ...      ...         ...         ...
# 74097  KarachiBuilding76227     NaN    house         NaN         NaN
# 74098  KarachiBuilding76228     NaN    house         NaN         NaN
# 74099  KarachiBuilding76229     NaN    house         NaN         NaN
# 74100  KarachiBuilding76230     NaN    house         NaN         NaN
# 74101  KarachiBuilding76231     NaN    house         NaN         NaN
#
#       addr_full addr_house addr_stree addr_city office  ...  \
# 0           NaN        NaN        NaN       NaN    NaN  ...
# 1           NaN        NaN        NaN       NaN    NaN  ...
# 2           NaN        NaN        NaN       NaN    NaN  ...
# 3           NaN        NaN        NaN       NaN    NaN  ...
# 4           NaN        NaN        NaN       NaN    NaN  ...
# ...         ...        ...        ...       ...    ...  ...
# 74097       NaN        NaN        NaN       NaN    NaN  ...
# 74098       NaN        NaN        NaN       NaN    NaN  ...
# 74099       NaN        NaN        NaN       NaN    NaN  ...
# 74100       NaN        NaN        NaN       NaN    NaN  ...
# 74101       NaN        NaN        NaN       NaN    NaN  ...
#
#                                              Public_10km  \
# 0      [1.01839515190166, 0.9840994363457459, 1.02681...
# 1      [0.894274160667676, 0.781061616788402, 0.90297...
# 2      [0.891681603674128, 0.847859370661188, 0.90030...
# 3      [0.815789999333003, 0.8540509548808641, 0.8243...
# 4      [0.8200928852120949, 0.8527978084118829, 0.828...
# ...                                                  ...
# 74097  [0.887130654708676, 0.785614423080518, 0.88867...
# 74098  [0.8874199651728529, 0.786772160205799, 0.8889...
# 74099  [0.885857699796133, 0.785886440214571, 0.88739...
# 74100  [0.886159765002446, 0.787048843800784, 0.88767...
# ...                                                  ...
# 74097  [0.80894132351224, 0.8223718005909121, 0.54103...
# 74098  [0.809131802009297, 0.823001035624101, 0.54030...
# 74099  [0.807644331143827, 0.8212653292368659, 0.5420...
# 74100  [0.807847032858134, 0.821908517920389, 0.54132...
# 74101  [0.807038133872368, 0.8212080428444649, 0.5419...
#
#                                              Sports_10km  \
# 0      [0.34003897145664, 0.337576689083984, 0.343706...
# 1      [0.13854135522501898, 0.139118552851967, 0.145...
# 2      [0.172532671843065, 0.170359494197652, 0.17660...
# 3      [0.135781052081297, 0.130839894857154, 0.13570...
# 4      [0.136335592287183, 0.131575712395374, 0.13657...
# ...                                                  ...
# 74097  [0.80894132351224, 0.8223718005909121, 0.54103...
# 74098  [0.809131802009297, 0.823001035624101, 0.54030...
# 74099  [0.807644331143827, 0.8212653292368659, 0.5420...
# 74100  [0.807847032858134, 0.821908517920389, 0.54132...
# 74101  [0.807038133872368, 0.8212080428444649, 0.5419...
#
#                                   Transport_1km  \
# 0                           [0.528517016848326]
# 1                           [0.310450583606515]
# 2                         [0.37333329503486795]
# 3                         [0.36773915031521903]
# 4                            [0.36691830357577]
# ...                                         ...
# 74097   [0.932008571005821, 0.9569016782870171]
# 74098   [0.9331152356187509, 0.956101468424156]
# 74099   [0.931563983452646, 0.9559252999876521]
# 74100   [0.9326818251095791, 0.955127296448967]
# 74101  [0.9323810078955261, 0.9545404265543069]
#
#                                    Transport_5km  \
# 0           [0.528517016848326, 1.8744648376244]
# 1        [0.310450583606515, 1.7170552370497898]
# 2        [0.37333329503486795, 1.73013291406938]
# 3      [0.36773915031521903, 1.6586762700923998]
# 4           [0.36691830357577, 1.66256421173862]
# ...                                          ...
# 74097    [0.932008571005821, 0.9569016782870171]
# 74098    [0.9331152356187509, 0.956101468424156]
# 74099    [0.931563983452646, 0.9559252999876521]
# 74100    [0.9326818251095791, 0.955127296448967]
# 74101   [0.9323810078955261, 0.9545404265543069]
#
#                                   Transport_10km
# 0           [0.528517016848326, 1.8744648376244]
# 1        [0.310450583606515, 1.7170552370497898]
# 2        [0.37333329503486795, 1.73013291406938]
# 3      [0.36773915031521903, 1.6586762700923998]
# 4           [0.36691830357577, 1.66256421173862]
# ...                                          ...
# 74097    [0.932008571005821, 0.9569016782870171]
# 74098    [0.9331152356187509, 0.956101468424156]
# 74099    [0.931563983452646, 0.9559252999876521]
# 74100    [0.9326818251095791, 0.955127296448967]
# 74101   [0.9323810078955261, 0.9545404265543069]
#
# [74102 rows x 58 columns]

# %%
# %%time
# Define columns
columns = ['Civic', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Transport']

# Define a function to apply element-wise
def transform_list(lst, val):
    return [round(val - x, 2) for x in lst]

# Use applymap to vectorize calculations
for col in columns:
    df[f'{col}_1km'] = df[f'{col}_1km'].map(lambda x: transform_list(x, 1))
    df[f'{col}_5km'] = df[f'{col}_5km'].map(lambda x: transform_list(x, 5))
    df[f'{col}_10km'] = df[f'{col}_10km'].map(lambda x: transform_list(x, 10))
# Out:
# CPU times: total: 1min
# Wall time: 1min 1s

# %%
# %%time
# Define columns
columns = ['Civic', 'Government', 'Hospital', 'Public', 'School', 'Sports', 'Transport']

# Initialize score columns
for col in columns:
    df[f'{col}_1km_Score'] = None
    df[f'{col}_5km_Score'] = None
    df[f'{col}_10km_Score'] = None

# Define a function to calculate scores
def calculate_scores(row, columns):
    for col in columns:
        row[f'{col}_1km_Score'] = sum(row[f'{col}_1km'])
        row[f'{col}_5km_Score'] = sum(row[f'{col}_5km'])
        row[f'{col}_10km_Score'] = sum(row[f'{col}_10km'])
    return row

# Apply the function across the dataframe
df = df.apply(lambda row: calculate_scores(row, columns), axis=1)
# Out:
# CPU times: total: 1min 14s
# Wall time: 1min 17s

# %%
df
# Out:
#                    Building name_en building  building_l  building_m  \
# 0          KarachiBuilding0     NaN      yes         NaN         NaN
# 1          KarachiBuilding1     NaN      yes         NaN         NaN
# 2          KarachiBuilding2     NaN      yes         NaN         NaN
# 3          KarachiBuilding3     NaN      yes         NaN         NaN
# 4          KarachiBuilding4     NaN      yes         NaN         NaN
# ...                     ...     ...      ...         ...         ...
# 74097  KarachiBuilding76227     NaN    house         NaN         NaN
# 74098  KarachiBuilding76228     NaN    house         NaN         NaN
# 74099  KarachiBuilding76229     NaN    house         NaN         NaN
# 74100  KarachiBuilding76230     NaN    house         NaN         NaN
# 74101  KarachiBuilding76231     NaN    house         NaN         NaN
#
#       addr_full addr_house addr_stree addr_city office  ... Public_10km_Score  \
# 0           NaN        NaN        NaN       NaN    NaN  ...             44.93
# 1           NaN        NaN        NaN       NaN    NaN  ...             45.63
# 2           NaN        NaN        NaN       NaN    NaN  ...             45.56
# 3           NaN        NaN        NaN       NaN    NaN  ...             45.87
# 4           NaN        NaN        NaN       NaN    NaN  ...             45.85
# ...         ...        ...        ...       ...    ...  ...               ...
# 74097       NaN        NaN        NaN       NaN    NaN  ...             45.66
# 74098       NaN        NaN        NaN       NaN    NaN  ...             45.66
# 74099       NaN        NaN        NaN       NaN    NaN  ...             45.66
# 74100       NaN        NaN        NaN       NaN    NaN  ...             45.66
# 74101       NaN        NaN        NaN       NaN    NaN  ...             45.66
#
#       School_1km_Score  School_5km_Score School_10km_Score  Sports_1km_Score  \
# 0                 3.69             23.69             48.69              3.45
# 1                 4.53             24.53             49.53              4.35
# 2                 4.37             24.37             49.37              4.15
# 3                 4.25             24.25             49.25              4.23
# 4                 4.24             24.24             49.24              4.24
# ...                ...               ...               ...               ...
# 74097             4.71             24.71             49.71              1.20
# 74098             4.72             24.72             49.72              1.20
# 74099             4.71             24.71             49.71              1.20
# 74100             4.71             24.71             49.71              1.20
# 74101             4.71             24.71             49.71              1.20
#
#        Sports_5km_Score Sports_10km_Score Transport_1km_Score  \
# 0                 23.45             48.45                0.47
# 1                 24.35             49.35                0.69
# 2                 24.15             49.15                0.63
# 3                 24.23             49.23                0.63
# 4                 24.24             49.24                0.63
# ...                 ...               ...                 ...
# 74097             21.20             46.20                0.11
# 74098             21.20             46.20                0.11
# 74099             21.20             46.20                0.11
# 74100             21.20             46.20                0.11
# 74101             21.20             46.20                0.12
#
#        Transport_5km_Score  Transport_10km_Score
# 0                     7.60                 17.60
# 1                     7.97                 17.97
# 2                     7.90                 17.90
# 3                     7.97                 17.97
# 4                     7.97                 17.97
# ...                    ...                   ...
# 74097                 8.11                 18.11
# 74098                 8.11                 18.11
# 74099                 8.11                 18.11
# 74100                 8.11                 18.11
# 74101                 8.12                 18.12
#
# [74102 rows x 79 columns]

# %%
df.columns[78]
# Out:
# 'Transport_10km_Score'

# %%
# Vectorized scaling operation
df.iloc[:, 58:79] = df.iloc[:, 58:79].apply(lambda col: (col - col.min()) / (col.max() - col.min()) * 10, axis=0)

# %%
# Optimized approach
try:
    df.iloc[:, 58:79] = df.iloc[:, 58:79].astype(float).round(2)
except Exception as e:
    print('Error:', e)

# %%
df
# Out:
#                    Building name_en building  building_l  building_m  \
# 0          KarachiBuilding0     NaN      yes         NaN         NaN
# 1          KarachiBuilding1     NaN      yes         NaN         NaN
# 2          KarachiBuilding2     NaN      yes         NaN         NaN
# 3          KarachiBuilding3     NaN      yes         NaN         NaN
# 4          KarachiBuilding4     NaN      yes         NaN         NaN
# ...                     ...     ...      ...         ...         ...
# 74097  KarachiBuilding76227     NaN    house         NaN         NaN
# 74098  KarachiBuilding76228     NaN    house         NaN         NaN
# 74099  KarachiBuilding76229     NaN    house         NaN         NaN
# 74100  KarachiBuilding76230     NaN    house         NaN         NaN
# 74101  KarachiBuilding76231     NaN    house         NaN         NaN
#
#       addr_full addr_house addr_stree addr_city office  ... Public_10km_Score  \
# 0           NaN        NaN        NaN       NaN    NaN  ...              8.41
# 1           NaN        NaN        NaN       NaN    NaN  ...              8.63
# 2           NaN        NaN        NaN       NaN    NaN  ...              8.61
# 3           NaN        NaN        NaN       NaN    NaN  ...              8.71
# 4           NaN        NaN        NaN       NaN    NaN  ...              8.71
# ...         ...        ...        ...       ...    ...  ...               ...
# 74097       NaN        NaN        NaN       NaN    NaN  ...              8.64
# 74098       NaN        NaN        NaN       NaN    NaN  ...              8.64
# 74099       NaN        NaN        NaN       NaN    NaN  ...              8.64
# 74100       NaN        NaN        NaN       NaN    NaN  ...              8.64
# 74101       NaN        NaN        NaN       NaN    NaN  ...              8.64
#
#       School_1km_Score  School_5km_Score School_10km_Score  Sports_1km_Score  \
# 0                 7.39              9.40              9.40              6.97
# 1                 9.08              9.79              9.79              8.79
# 2                 8.76              9.71              9.71              8.38
# 3                 8.52              9.66              9.66              8.55
# 4                 8.50              9.65              9.65              8.57
# ...                ...               ...               ...               ...
# 74097             9.44              9.87              9.87              2.42
# 74098             9.46              9.87              9.87              2.42
# 74099             9.44              9.87              9.87              2.42
# 74100             9.44              9.87              9.87              2.42
# 74101             9.44              9.87              9.87              2.42
#
#        Sports_5km_Score Sports_10km_Score Transport_1km_Score  \
# 0                  9.40              9.50                 4.7
# 1                  9.76              9.80                 6.9
# 2                  9.68              9.73                 6.3
# 3                  9.71              9.76                 6.3
# 4                  9.72              9.76                 6.3
# ...                 ...               ...                 ...
# 74097              8.50              8.75                 1.1
# 74098              8.50              8.75                 1.1
# 74099              8.50              8.75                 1.1
# 74100              8.50              8.75                 1.1
# 74101              8.50              8.75                 1.2
#
#        Transport_5km_Score  Transport_10km_Score
# 0                     9.00                  9.27
# 1                     9.44                  9.59
# 2                     9.36                  9.53
# 3                     9.44                  9.59
# 4                     9.44                  9.59
# ...                    ...                   ...
# 74097                 9.61                  9.71
# 74098                 9.61                  9.71
# 74099                 9.61                  9.71
# 74100                 9.61                  9.71
# 74101                 9.62                  9.72
#
# [74102 rows x 79 columns]

# %%
df.columns
# Out:
# Index(['Building', 'name_en', 'building', 'building_l', 'building_m',
#        'addr_full', 'addr_house', 'addr_stree', 'addr_city', 'office',
#        'source', 'name_ur', 'osm_id', 'osm_type', 'Shape_Leng', 'Shape_Area',
#        'ADM2_EN', 'ADM2_PCODE', 'ADM2_REF', 'ADM2ALT1EN', 'ADM2ALT2EN',
#        'ADM1_EN', 'ADM1_PCODE', 'ADM0_EN', 'ADM0_PCODE', 'date', 'validOn',
#        'validTo', 'lon', 'lat', 'Civic', 'Government', 'Hospital', 'Public',
#        'School', 'Sports', 'Transport', 'Civic_1km', 'Civic_5km', 'Civic_10km',
#        'Government_1km', 'Government_5km', 'Government_10km', 'Hospital_1km',
#        'Hospital_5km', 'Hospital_10km', 'Public_1km', 'Public_5km',
#        'Public_10km', 'School_1km', 'School_5km', 'School_10km', 'Sports_1km',
#        'Sports_5km', 'Sports_10km', 'Transport_1km', 'Transport_5km',
#        'Transport_10km', 'Civic_1km_Score', 'Civic_5km_Score',
#        'Civic_10km_Score', 'Government_1km_Score', 'Government_5km_Score',
#        'Government_10km_Score', 'Hospital_1km_Score', 'Hospital_5km_Score',
#        'Hospital_10km_Score', 'Public_1km_Score', 'Public_5km_Score',
#        'Public_10km_Score', 'School_1km_Score', 'School_5km_Score',
#        'School_10km_Score', 'Sports_1km_Score', 'Sports_5km_Score',
#        'Sports_10km_Score', 'Transport_1km_Score', 'Transport_5km_Score',
#        'Transport_10km_Score'],
#       dtype='object')

# %%
df = df[['Building',  'lon', 'lat', 'Civic_1km_Score', 'Civic_5km_Score',
       'Civic_10km_Score', 'Government_1km_Score', 'Government_5km_Score',
       'Government_10km_Score', 'Hospital_1km_Score', 'Hospital_5km_Score',
       'Hospital_10km_Score', 'Public_1km_Score', 'Public_5km_Score',
       'Public_10km_Score', 'School_1km_Score', 'School_5km_Score',
       'School_10km_Score', 'Sports_1km_Score', 'Sports_5km_Score',
       'Sports_10km_Score', 'Transport_1km_Score', 'Transport_5km_Score',
       'Transport_10km_Score']]

# %%
df.to_csv('KarachiScoreRAW.csv', index = False)
